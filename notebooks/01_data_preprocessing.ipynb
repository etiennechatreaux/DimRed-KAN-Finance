# %% [markdown]
# # Fetch the data from yfinance

# %%
import pandas as pd
import yfinance as yf
import time
import os
import random
import tqdm
import numpy as np

def fetch_data(ticker, start='2015-01-01', end='2025-01-01', wait=True):
    if os.path.exists(f'data/raw/autoadjusted/{ticker}.csv'):
        print(f'{ticker} already exists')
        return pd.read_csv(f'data/raw/autoadjusted/{ticker}.csv')
    else:
        try:
            data = yf.download(ticker, start=start, end=end, auto_adjust=True)
            data.to_csv(f'data/raw/autoadjusted/{ticker}.csv')
            print(f'{ticker} fetched and saved')
            if wait:
                time.sleep(random.randint(4, 8))
            return data
        except Exception as e:
            print(f'Error fetching {ticker}: {e}')
            return None
        
def get_sp500_tickers():
    """
    Get list of S&P 500 tickers from Wikipedia
    """
    try:
        # Get S&P 500 table from Wikipedia
        url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
        table = pd.read_html(url)[0]
        
        # Get tickers from first column
        tickers = table['Symbol'].tolist()
        
        print(f"Retrieved {len(tickers)} S&P 500 tickers")
        return tickers
        
    except Exception as e:
        print(f"Error getting S&P 500 tickers: {e}")
        return None
    
def format_data(data):
    try:
        data = data.iloc[2:].copy()
        data['Date'] = pd.to_datetime(data['Price'])
        data.drop('Price', axis=1, inplace=True)
        data.set_index('Date', inplace=True)
    except Exception as e:
        print(f"Error formatting data for {data.name}: {e}")
        return None
    return data
    
    
    
def import_all_data(folder_with_csv):
    all_data = {}
    for file in os.listdir(folder_with_csv):
        data = pd.read_csv(os.path.join(folder_with_csv, file))
        filename = file.split('.')[0]
        all_data[filename] = data
    return all_data


def verify_data(data_df, first='2010-01-04', last='2024-12-31'):
    # Check if first date is 2015-01-02 and last date is 2024-12-31
    first_date = data_df.index[0]
    last_date = data_df.index[-1]
    
    expected_first = pd.Timestamp(first)
    expected_last = pd.Timestamp(last)
    
    if first_date != expected_first or last_date != expected_last:
        print("Error")
        print(f"Expected range: {expected_first} to {expected_last}")
        print(f"Actual range: {first_date} to {last_date}")
        return False
        
    return True

# %%
sp500_tickers = get_sp500_tickers()
print(sp500_tickers[:10])
# Out:
# Retrieved 503 S&P 500 tickers
# ['MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ADBE', 'AMD', 'AES', 'AFL', 'A']

# %%
csv_count = len([f for f in os.listdir('data/raw') if f.endswith('.csv')])
print(f"Number of CSV files in data/raw: {csv_count}")
# Out:
# Number of CSV files in data/raw: 503

# %%
start = '2010-01-01'
end = '2025-01-01'
    
for ticker in tqdm.tqdm(sp500_tickers):
    csv_path = os.path.join('data/raw/autoadjusted/', f'{ticker}.csv')
    if os.path.exists(csv_path):
        print(f"{ticker} already exists")
    else:
        data = fetch_data(ticker, start, end, wait=True)
# Out:
# 100%|██████████| 503/503 [00:00<00:00, 6668.17it/s]
# MMM already exists
# AOS already exists
# ABT already exists
# ABBV already exists
# ACN already exists
# ADBE already exists
# AMD already exists
# AES already exists
# AFL already exists
# A already exists
# APD already exists
# ABNB already exists
# AKAM already exists
# ALB already exists
# ARE already exists
# ALGN already exists
# ALLE already exists
# LNT already exists
# ALL already exists
# GOOGL already exists
# GOOG already exists
# MO already exists
# AMZN already exists
# AMCR already exists
# AEE already exists
# AEP already exists
# AXP already exists
# AIG already exists
# AMT already exists
# AWK already exists
# AMP already exists
# AME already exists
# AMGN already exists
# APH already exists
# ADI already exists
# AON already exists
# APA already exists
# APO already exists
# AAPL already exists
# AMAT already exists
# APTV already exists
# ACGL already exists
# ADM already exists
# ANET already exists
# AJG already exists
# AIZ already exists
# T already exists
# ATO already exists
# ADSK already exists
# ADP already exists
# AZO already exists
# AVB already exists
# AVY already exists
# AXON already exists
# BKR already exists
# BALL already exists
# BAC already exists
# BAX already exists
# BDX already exists
# BRK.B already exists
# BBY already exists
# TECH already exists
# BIIB already exists
# BLK already exists
# BX already exists
# XYZ already exists
# BK already exists
# BA already exists
# BKNG already exists
# BSX already exists
# BMY already exists
# AVGO already exists
# BR already exists
# BRO already exists
# BF.B already exists
# BLDR already exists
# BG already exists
# BXP already exists
# CHRW already exists
# CDNS already exists
# CZR already exists
# CPT already exists
# CPB already exists
# COF already exists
# CAH already exists
# KMX already exists
# CCL already exists
# CARR already exists
# CAT already exists
# CBOE already exists
# CBRE already exists
# CDW already exists
# COR already exists
# CNC already exists
# CNP already exists
# CF already exists
# CRL already exists
# SCHW already exists
# CHTR already exists
# CVX already exists
# CMG already exists
# CB already exists
# CHD already exists
# CI already exists
# CINF already exists
# CTAS already exists
# CSCO already exists
# C already exists
# CFG already exists
# CLX already exists
# CME already exists
# CMS already exists
# KO already exists
# CTSH already exists
# COIN already exists
# CL already exists
# CMCSA already exists
# CAG already exists
# COP already exists
# ED already exists
# STZ already exists
# CEG already exists
# COO already exists
# CPRT already exists
# GLW already exists
# CPAY already exists
# CTVA already exists
# CSGP already exists
# COST already exists
# CTRA already exists
# CRWD already exists
# CCI already exists
# CSX already exists
# CMI already exists
# CVS already exists
# DHR already exists
# DRI already exists
# DDOG already exists
# DVA already exists
# DAY already exists
# DECK already exists
# DE already exists
# DELL already exists
# DAL already exists
# DVN already exists
# DXCM already exists
# FANG already exists
# DLR already exists
# DG already exists
# DLTR already exists
# D already exists
# DPZ already exists
# DASH already exists
# DOV already exists
# DOW already exists
# DHI already exists
# DTE already exists
# DUK already exists
# DD already exists
# EMN already exists
# ETN already exists
# EBAY already exists
# ECL already exists
# EIX already exists
# EW already exists
# EA already exists
# ELV already exists
# EMR already exists
# ENPH already exists
# ETR already exists
# EOG already exists
# EPAM already exists
# EQT already exists
# EFX already exists
# EQIX already exists
# EQR already exists
# ERIE already exists
# ESS already exists
# EL already exists
# EG already exists
# EVRG already exists
# ES already exists
# EXC already exists
# EXE already exists
# EXPE already exists
# EXPD already exists
# EXR already exists
# XOM already exists
# FFIV already exists
# FDS already exists
# FICO already exists
# FAST already exists
# FRT already exists
# FDX already exists
# FIS already exists
# FITB already exists
# FSLR already exists
# FE already exists
# FI already exists
# F already exists
# FTNT already exists
# FTV already exists
# FOXA already exists
# FOX already exists
# BEN already exists
# FCX already exists
# GRMN already exists
# IT already exists
# GE already exists
# GEHC already exists
# GEV already exists
# GEN already exists
# GNRC already exists
# GD already exists
# GIS already exists
# GM already exists
# GPC already exists
# GILD already exists
# GPN already exists
# GL already exists
# GDDY already exists
# GS already exists
# HAL already exists
# HIG already exists
# HAS already exists
# HCA already exists
# DOC already exists
# HSIC already exists
# HSY already exists
# HPE already exists
# HLT already exists
# HOLX already exists
# HD already exists
# HON already exists
# HRL already exists
# HST already exists
# HWM already exists
# HPQ already exists
# HUBB already exists
# HUM already exists
# HBAN already exists
# HII already exists
# IBM already exists
# IEX already exists
# IDXX already exists
# ITW already exists
# INCY already exists
# IR already exists
# PODD already exists
# INTC already exists
# ICE already exists
# IFF already exists
# IP already exists
# IPG already exists
# INTU already exists
# ISRG already exists
# IVZ already exists
# INVH already exists
# IQV already exists
# IRM already exists
# JBHT already exists
# JBL already exists
# JKHY already exists
# J already exists
# JNJ already exists
# JCI already exists
# JPM already exists
# K already exists
# KVUE already exists
# KDP already exists
# KEY already exists
# KEYS already exists
# KMB already exists
# KIM already exists
# KMI already exists
# KKR already exists
# KLAC already exists
# KHC already exists
# KR already exists
# LHX already exists
# LH already exists
# LRCX already exists
# LW already exists
# LVS already exists
# LDOS already exists
# LEN already exists
# LII already exists
# LLY already exists
# LIN already exists
# LYV already exists
# LKQ already exists
# LMT already exists
# L already exists
# LOW already exists
# LULU already exists
# LYB already exists
# MTB already exists
# MPC already exists
# MKTX already exists
# MAR already exists
# MMC already exists
# MLM already exists
# MAS already exists
# MA already exists
# MTCH already exists
# MKC already exists
# MCD already exists
# MCK already exists
# MDT already exists
# MRK already exists
# META already exists
# MET already exists
# MTD already exists
# MGM already exists
# MCHP already exists
# MU already exists
# MSFT already exists
# MAA already exists
# MRNA already exists
# MHK already exists
# MOH already exists
# TAP already exists
# MDLZ already exists
# MPWR already exists
# MNST already exists
# MCO already exists
# MS already exists
# MOS already exists
# MSI already exists
# MSCI already exists
# NDAQ already exists
# NTAP already exists
# NFLX already exists
# NEM already exists
# NWSA already exists
# NWS already exists
# NEE already exists
# NKE already exists
# NI already exists
# NDSN already exists
# NSC already exists
# NTRS already exists
# NOC already exists
# NCLH already exists
# NRG already exists
# NUE already exists
# NVDA already exists
# NVR already exists
# NXPI already exists
# ORLY already exists
# OXY already exists
# ODFL already exists
# OMC already exists
# ON already exists
# OKE already exists
# ORCL already exists
# OTIS already exists
# PCAR already exists
# PKG already exists
# PLTR already exists
# PANW already exists
# PSKY already exists
# PH already exists
# PAYX already exists
# PAYC already exists
# PYPL already exists
# PNR already exists
# PEP already exists
# PFE already exists
# PCG already exists
# PM already exists
# PSX already exists
# PNW already exists
# PNC already exists
# POOL already exists
# PPG already exists
# PPL already exists
# PFG already exists
# PG already exists
# PGR already exists
# PLD already exists
# PRU already exists
# PEG already exists
# PTC already exists
# PSA already exists
# PHM already exists
# PWR already exists
# QCOM already exists
# DGX already exists
# RL already exists
# RJF already exists
# RTX already exists
# O already exists
# REG already exists
# REGN already exists
# RF already exists
# RSG already exists
# RMD already exists
# RVTY already exists
# ROK already exists
# ROL already exists
# ROP already exists
# ROST already exists
# RCL already exists
# SPGI already exists
# CRM already exists
# SBAC already exists
# SLB already exists
# STX already exists
# SRE already exists
# NOW already exists
# SHW already exists
# SPG already exists
# SWKS already exists
# SJM already exists
# SW already exists
# SNA already exists
# SOLV already exists
# SO already exists
# LUV already exists
# SWK already exists
# SBUX already exists
# STT already exists
# STLD already exists
# STE already exists
# SYK already exists
# SMCI already exists
# SYF already exists
# SNPS already exists
# SYY already exists
# TMUS already exists
# TROW already exists
# TTWO already exists
# TPR already exists
# TRGP already exists
# TGT already exists
# TEL already exists
# TDY already exists
# TER already exists
# TSLA already exists
# TXN already exists
# TPL already exists
# TXT already exists
# TMO already exists
# TJX already exists
# TKO already exists
# TTD already exists
# TSCO already exists
# TT already exists
# TDG already exists
# TRV already exists
# TRMB already exists
# TFC already exists
# TYL already exists
# TSN already exists
# USB already exists
# UBER already exists
# UDR already exists
# ULTA already exists
# UNP already exists
# UAL already exists
# UPS already exists
# URI already exists
# UNH already exists
# UHS already exists
# VLO already exists
# VTR already exists
# VLTO already exists
# VRSN already exists
# VRSK already exists
# VZ already exists
# VRTX already exists
# VTRS already exists
# VICI already exists
# V already exists
# VST already exists
# VMC already exists
# WRB already exists
# GWW already exists
# WAB already exists
# WBA already exists
# WMT already exists
# DIS already exists
# WBD already exists
# WM already exists
# WAT already exists
# WEC already exists
# WFC already exists
# WELL already exists
# WST already exists
# WDC already exists
# WY already exists
# WSM already exists
# WMB already exists
# WTW already exists
# WDAY already exists
# WYNN already exists
# XEL already exists
# XYL already exists
# YUM already exists
# ZBRA already exists
# ZBH already exists
# ZTS already exists

# %%
raw_count = len([f for f in os.listdir('data/raw') if f.endswith('.csv')])
autoadj_count = len([f for f in os.listdir('data/raw/autoadjusted') if f.endswith('.csv')])

print(f"Number of CSV files in data/raw: {raw_count}")
print(f"Number of CSV files in data/raw/autoadjusted: {autoadj_count}")
# Out:
# Number of CSV files in data/raw: 503
# Number of CSV files in data/raw/autoadjusted: 503

# %%
def verify_date_range(df, start="2010-01-04", end="2024-12-31"):
    # All stocks have different start dates, so only check end date
    if len(df.index) == 0:
        return False
    if df.index[-1].strftime('%Y-%m-%d') != end:
        return False
    return True

def verify_nan_values(df):
    if df.isna().any().any():
        return False
    return True

good_data = {}
bad_data = {}

for file in os.listdir('data/raw/autoadjusted'):
    if not file.endswith('.csv'):
        continue
        
    ticker = file[:-4]  # Remove .csv extension
    csv_path = os.path.join('data/raw/autoadjusted', file)
    
    try:
        df = pd.read_csv(csv_path, skiprows=[1,2]) # Skip Ticker and Date rows
        df.rename(columns={'Price': 'Date'}, inplace=True)
        df['Date'] = pd.to_datetime(df['Date'])
        df.set_index('Date', inplace=True)
        
        if not verify_date_range(df) or not verify_nan_values(df):
            print(f"Verification failed for {ticker}")
            if len(df.index) > 0:
                print(f"Date range: {df.index[0]} to {df.index[-1]}")
            else:
                print("Empty dataframe")
            print(f"Nan values: {df.isna().any().any()}")
            print("--------------------------------")
            bad_data[ticker] = df
        else:
            good_data[ticker] = df
            csv_path = os.path.join('data/raw', file)
            # df.to_csv(csv_path)
            # break
            
    except Exception as e:
        print(f"Error processing {ticker}: {str(e)}")
        print("--------------------------------")

# %%
ticker = 'A'
df = pd.read_csv(f'data/raw/{ticker}.csv')
df.set_index('Date', inplace=True)
df.index = pd.to_datetime(df.index)
df
# Out:
#                  Close        High         Low        Open   Volume
# Date
# 2010-01-04   19.931620   20.141761   19.823364   19.988930  3815561
# 2010-01-05   19.715111   19.880677   19.587751   19.874309  4186031
# 2010-01-06   19.645058   19.740576   19.587745   19.645058  3243779
# 2010-01-07   19.619595   19.625962   19.422188   19.600489  3095172
# 2010-01-08   19.613226   19.645067   19.358510   19.511340  3733918
# ...                ...         ...         ...         ...      ...
# 2024-12-24  135.276016  135.276016  133.337810  133.785098   370200
# 2024-12-26  135.007660  135.156746  134.152866  134.192617   556600
# 2024-12-27  134.719406  135.395297  133.775161  133.804978   631800
# 2024-12-30  133.606186  134.769101  132.433337  133.586303   993600
# 2024-12-31  133.773468  135.336854  133.464778  134.241487   719600
#
# [3774 rows x 5 columns]

# %% [markdown]
# # Preprocess data

# %%
# Iterate directly over files in data/raw directory
good_data = {}
error_data = {}

for file in os.listdir('data/raw'):
    if not file.endswith('.csv'):
        continue
        
    ticker = file[:-4]  # Remove .csv extension
    csv_path = os.path.join('data/raw', file)
    
    try:
        data = pd.read_csv(csv_path)
        data.set_index('Date', inplace=True)
        data.index = pd.to_datetime(data.index)
        
        if verify_data(data):
            good_data[ticker] = data
        else:
            error_data[ticker] = data
            print(f"Data verification failed for {ticker}")
            
    except Exception as e:
        print(f"Error processing {ticker}: {str(e)}")
        error_data[ticker] = None
# Out:
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2013-01-02 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for ABBV
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2020-12-10 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for ABNB
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2013-11-18 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for ALLE
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2012-05-15 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for AMCR
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2014-06-06 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for ANET
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2011-03-30 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for APO
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2011-11-17 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for APTV
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2020-03-19 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for CARR
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2010-06-15 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for CBOE
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2013-06-27 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for CDW
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2022-01-19 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for CEG
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2014-09-24 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for CFG
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2010-01-05 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for CHTR
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2021-04-14 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for COIN
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2010-12-15 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for CPAY
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2019-06-12 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for CRWD
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2019-05-24 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for CTVA
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2014-09-22 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for CZR
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2020-12-09 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for DASH
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2018-04-26 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for DAY
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2019-09-19 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for DDOG
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2016-08-17 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for DELL
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2019-03-20 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for DOW
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2012-03-30 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for ENPH
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2012-02-08 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for EPAM
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2021-02-10 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for EXE
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2012-10-12 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for FANG
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2019-03-13 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for FOX
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2019-03-12 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for FOXA
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2016-07-05 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for FTV
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2015-03-31 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for GDDY
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2022-12-15 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for GEHC
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2024-03-27 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for GEV
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2010-11-18 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for GM
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2010-02-11 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for GNRC
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2011-03-10 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for HCA
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2011-03-22 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for HII
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2013-12-12 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for HLT
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2015-10-19 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for HPE
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2016-11-01 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for HWM
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2017-02-01 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for INVH
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2013-05-09 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for IQV
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2017-05-12 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for IR
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2014-10-20 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for KEYS
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2015-07-06 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for KHC
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2010-07-15 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for KKR
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2011-02-11 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for KMI
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2023-05-04 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for KVUE
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2016-11-10 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for LW
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2010-04-28 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for LYB
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2012-05-18 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for META
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2011-06-24 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for MPC
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2018-12-07 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for MRNA
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2013-01-18 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for NCLH
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2012-06-29 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for NOW
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2013-06-19 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for NWS
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2013-06-19 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for NWSA
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2010-08-06 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for NXPI
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2020-03-19 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for OTIS
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2012-07-20 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for PANW
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2014-04-15 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for PAYC
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2020-09-30 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for PLTR
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2012-04-12 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for PSX
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2015-07-06 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for PYPL
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2024-03-26 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for SOLV
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2014-07-31 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for SYF
# Error processing tickers_sectors: "None of ['Date'] are in the columns"
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2010-12-07 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for TRGP
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2010-06-29 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for TSLA
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2016-09-21 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for TTD
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2019-05-10 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for UBER
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2018-01-02 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for VICI
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2023-10-04 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for VLTO
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2016-10-05 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for VST
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2012-10-12 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for WDAY
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2011-10-13 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for XYL
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2015-11-19 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for XYZ
# Error
# Expected range: 2010-01-04 00:00:00 to 2024-12-31 00:00:00
# Actual range: 2013-02-01 00:00:00 to 2024-12-31 00:00:00
# Data verification failed for ZTS

# %%
print(len(good_data))
print(len(error_data))
# Out:
# 423
# 78

# %%
close_prices = {ticker: data['Close'] for ticker, data in good_data.items()}
dataset = pd.DataFrame(close_prices)

if not os.path.exists("data/processed/dataset_prices.csv"):
    dataset.to_csv("data/processed/dataset_prices.csv")
    print("Dataset saved!")
    
dataset
# Out:
#                      A        AAPL         ABT       ACGL         ACN  \
# Date
# 2010-01-04   19.931620    6.424604   18.496670   7.601905   31.492178
# 2010-01-05   19.715111    6.435713   18.347229   7.576549   31.686810
# 2010-01-06   19.645058    6.333344   18.449114   7.543795   32.023655
# 2010-01-07   19.619595    6.321636   18.601961   7.499420   31.993710
# 2010-01-08   19.613226    6.363666   18.697060   7.484628   31.866465
# ...                ...         ...         ...        ...         ...
# 2024-12-24  135.276016  257.286682  113.126747  92.669998  356.539642
# 2024-12-26  135.007660  258.103729  113.629486  92.930000  355.356537
# 2024-12-27  134.719406  254.685867  113.353470  92.339996  351.166321
# 2024-12-30  133.606186  251.307877  111.194641  91.889999  347.528290
# 2024-12-31  133.773468  249.534180  111.500229  92.349998  346.838165
#
#                   ADBE         ADI        ADM         ADP        ADSK  ...  \
# Date                                                                   ...
# 2010-01-04   37.090000   22.062073  20.791342   26.033312   25.670000  ...
# 2010-01-05   37.700001   22.027241  20.903652   25.893505   25.280001  ...
# 2010-01-06   37.619999   21.985449  20.850796   25.832731   25.340000  ...
# 2010-01-07   36.889999   21.811291  20.632776   25.820568   25.480000  ...
# 2010-01-08   36.689999   21.936684  20.375113   25.784111   26.260000  ...
# ...                ...         ...        ...         ...         ...  ...
# 2024-12-24  447.940002  216.161041  49.560802  293.422546  301.230011  ...
# 2024-12-26  450.160004  216.131317  49.541222  294.184692  300.279999  ...
# 2024-12-27  446.480011  215.070786  49.511856  293.145447  297.589996  ...
# 2024-12-30  445.799988  210.679962  49.012627  289.968323  297.529999  ...
# 2024-12-31  444.679993  210.580856  49.453121  289.730804  295.570007  ...
#
#                    WSM         WST         WTW         WY       WYNN  \
# Date
# 2010-01-04    7.264576   17.557016   52.100517   9.568550  40.966465
# 2010-01-05    7.466855   17.334608   51.983734   9.771677  43.458023
# 2010-01-06    7.731910   17.165573   52.820610   9.663627  42.887981
# 2010-01-07    8.101590   17.218956   52.664909   9.620409  43.803902
# 2010-01-08    7.976042   17.214504   52.606548   9.531811  43.490051
# ...                ...         ...         ...        ...        ...
# 2024-12-24  185.572479  331.955566  313.332672  27.837299  88.309021
# 2024-12-26  185.473633  332.613922  315.156952  27.748648  88.836212
# 2024-12-27  183.911789  332.404419  313.610291  27.571339  88.209557
# 2024-12-30  184.366486  328.015228  310.566467  27.472834  85.374672
# 2024-12-31  183.051788  326.758301  311.441437  27.728945  85.702927
#
#                   XEL         XOM         YUM         ZBH        ZBRA
# Date
# 2010-01-04  12.367372   38.568714   18.697779   51.990017   28.670000
# 2010-01-05  12.220693   38.719311   18.633829   53.635796   28.620001
# 2010-01-06  12.244164   39.053955   18.500622   53.618462   28.400000
# 2010-01-07  12.191360   38.931263   18.495293   54.848499   27.690001
# 2010-01-08  12.197227   38.775097   18.500622   53.696442   27.600000
# ...               ...         ...         ...         ...         ...
# 2024-12-24  66.534348  104.494308  133.709183  106.553841  395.440002
# 2024-12-26  66.505081  104.582695  134.699615  106.504189  396.850006
# 2024-12-27  66.466064  104.572876  133.936981  106.126839  389.070007
# 2024-12-30  65.929565  103.865776  132.243332  104.902634  383.850006
# 2024-12-31  65.861290  105.643356  132.877213  105.131546  386.220001
#
# [3774 rows x 423 columns]

# %%
# Calculate returns and log returns 
dataset = pd.read_csv('data/processed/dataset_prices.csv')
dataset = dataset.set_index('Date')
dataset = dataset.astype(float)

# Calculate simple returns
returns = dataset.pct_change()
# Calculate log returns
log_returns = np.log(dataset/dataset.shift(1))

# Save both returns datasets if they don't exist
if not os.path.exists("data/processed/dataset_returns.csv"):
    returns.to_csv("data/processed/dataset_returns.csv")
    print("Returns dataset saved!")
    
if not os.path.exists("data/processed/dataset_log_returns.csv"):
    log_returns.to_csv("data/processed/dataset_log_returns.csv") 
    print("Log returns dataset saved!")
    
returns
# Out:
# Returns dataset saved!
# Log returns dataset saved!
#                    A      AAPL       ABT      ACGL       ACN      ADBE  \
# Date
# 2010-01-04       NaN       NaN       NaN       NaN       NaN       NaN
# 2010-01-05 -0.010863  0.001729 -0.008079 -0.003336  0.006180  0.016446
# 2010-01-06 -0.003553 -0.015906  0.005553 -0.004323  0.010630 -0.002122
# 2010-01-07 -0.001296 -0.001849  0.008285 -0.005882 -0.000935 -0.019405
# 2010-01-08 -0.000325  0.006648  0.005112 -0.001972 -0.003977 -0.005422
# ...              ...       ...       ...       ...       ...       ...
# 2024-12-24  0.011144  0.011478  0.003937  0.006298  0.007972  0.002686
# 2024-12-26 -0.001984  0.003176  0.004444  0.002806 -0.003318  0.004956
# 2024-12-27 -0.002135 -0.013242 -0.002429 -0.006349 -0.011792 -0.008175
# 2024-12-30 -0.008263 -0.013263 -0.019045 -0.004873 -0.010360 -0.001523
# 2024-12-31  0.001252 -0.007058  0.002748  0.005006 -0.001986 -0.002512
#
#                  ADI       ADM       ADP      ADSK  ...       WSM       WST  \
# Date                                                ...
# 2010-01-04       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2010-01-05 -0.001579  0.005402 -0.005370 -0.015193  ...  0.027845 -0.012668
# 2010-01-06 -0.001897 -0.002529 -0.002347  0.002373  ...  0.035498 -0.009751
# 2010-01-07 -0.007922 -0.010456 -0.000471  0.005525  ...  0.047812  0.003110
# 2010-01-08  0.005749 -0.012488 -0.001412  0.030612  ... -0.015497 -0.000259
# ...              ...       ...       ...       ...  ...       ...       ...
# 2024-12-24  0.014891  0.004364  0.007853  0.012572  ...  0.006487  0.009710
# 2024-12-26 -0.000138 -0.000395  0.002597 -0.003154  ... -0.000533  0.001983
# 2024-12-27 -0.004907 -0.000593 -0.003533 -0.008958  ... -0.008421 -0.000630
# 2024-12-30 -0.020416 -0.010083 -0.010838 -0.000202  ...  0.002472 -0.013204
# 2024-12-31 -0.000470  0.008987 -0.000819 -0.006588  ... -0.007131 -0.003832
#
#                  WTW        WY      WYNN       XEL       XOM       YUM  \
# Date
# 2010-01-04       NaN       NaN       NaN       NaN       NaN       NaN
# 2010-01-05 -0.002241  0.021229  0.060819 -0.011860  0.003905 -0.003420
# 2010-01-06  0.016099 -0.011058 -0.013117  0.001921  0.008643 -0.007149
# 2010-01-07 -0.002948 -0.004472  0.021356 -0.004313 -0.003142 -0.000288
# 2010-01-08 -0.001108 -0.009209 -0.007165  0.000481 -0.004011  0.000288
# ...              ...       ...       ...       ...       ...       ...
# 2024-12-24  0.005248  0.006410  0.007604  0.007236  0.000941  0.008516
# 2024-12-26  0.005822 -0.003185  0.005970 -0.000440  0.000846  0.007407
# 2024-12-27 -0.004908 -0.006390 -0.007054 -0.000587 -0.000094 -0.005662
# 2024-12-30 -0.009706 -0.003573 -0.032138 -0.008072 -0.006762 -0.012645
# 2024-12-31  0.002817  0.009322  0.003845 -0.001036  0.017114  0.004793
#
#                  ZBH      ZBRA
# Date
# 2010-01-04       NaN       NaN
# 2010-01-05  0.031656 -0.001744
# 2010-01-06 -0.000323 -0.007687
# 2010-01-07  0.022941 -0.025000
# 2010-01-08 -0.021004 -0.003250
# ...              ...       ...
# 2024-12-24  0.004494  0.012262
# 2024-12-26 -0.000466  0.003566
# 2024-12-27 -0.003543 -0.019604
# 2024-12-30 -0.011535 -0.013417
# 2024-12-31  0.002182  0.006174
#
# [3774 rows x 423 columns]

# %% [markdown]
# # Process sector datasets

# %%
# Fetch S&P 500 sectors from Wikipedia
import pandas as pd

# Read the S&P 500 table from Wikipedia
sp500_wiki = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]

sectors_df = sp500_wiki[['Symbol', 'GICS Sector']].set_index('Symbol')
our_tickers = dataset.columns.tolist()

# Create mapping of tickers to sectors for our dataset
sectors_mapping = {}
for ticker in our_tickers:
    if ticker in sectors_df.index:
        sectors_mapping[ticker] = sectors_df.loc[ticker, 'GICS Sector']
    else:
        print(f"Ticker {ticker} not found in S&P 500")
        sectors_mapping[ticker] = 'unknown'

sectors_df = pd.DataFrame.from_dict(sectors_mapping, orient='index', columns=['Sector'])
if not os.path.exists("data/raw/tickers_sectors.csv"):
    sectors_df.to_csv("data/raw/tickers_sectors.csv")
    print("Sectors mapping saved!")
    
    
sectors_df.Sector.unique()
# Out:
# Sectors mapping saved!
# array(['Health Care', 'Information Technology', 'Financials',
#        'Consumer Staples', 'Industrials', 'Utilities', 'Materials',
#        'Real Estate', 'Consumer Discretionary', 'Energy',
#        'Communication Services'], dtype=object)

# %%
sectors = pd.read_csv("data/raw/tickers_sectors.csv", index_col=0)
sector_list = sectors.Sector.unique().tolist()

# Create sectoral datasets
for sector in sectors.Sector.unique():
    # Get tickers for this sector
    sector_tickers = sectors[sectors.Sector == sector].index.tolist()
    
    sector_returns = returns[sector_tickers]
    sector_log_returns = log_returns[sector_tickers]
    
    sector_dir = f"data/processed/sectors/{sector.lower().replace(' ', '_')}"
    if not os.path.exists(sector_dir):
        os.makedirs(sector_dir)
        
    # Save datasets
    sector_returns.to_csv(f"{sector_dir}/returns.csv")
    sector_log_returns.to_csv(f"{sector_dir}/log_returns.csv")
    
print("Sectoral datasets created!")
# Out:
# Sectoral datasets created!
