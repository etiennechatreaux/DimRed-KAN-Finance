# %%
import pandas as pd
from pathlib import Path
import torch
import sys
import numpy as np
sys.path.append('../src')

from models.ae_kan import KANAutoencoder

data_dir = Path("../data/processed/sectors")
sectors_list = [d.name for d in data_dir.iterdir() if d.is_dir() and d.name != 'unknown']

sector_log_returns = {}
for sector in sectors_list:
    returns_path = data_dir / sector / "log_returns.csv"
    df = pd.read_csv(returns_path, index_col=0)
    sector_log_returns[sector] = df.iloc[1:]  # Skip first row with NaN values
    
    
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"Total memory: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.1f} GB")
    print(f"Memory available: {torch.cuda.mem_get_info()[0] / 1024**3:.1f} GB")

print(f"Device : {device}")
# Out:
# GPU: NVIDIA GeForce RTX 3070 Laptop GPU
# Total memory: 8.0 GB
# Memory available: 6.9 GB
# Device : cuda

# %%
for sector in sector_log_returns:
    print(sector, sector_log_returns[sector].shape[1])
# Out:
# communication_services 17
# consumer_discretionary 43
# consumer_staples 33
# energy 16
# financials 64
# health_care 53
# industrials 64
# information_technology 53
# materials 22
# real_estate 29
# utilities 29

# %%
# Functions

def preprocessing_dataset(
    log_returns_df: pd.DataFrame,
    win: int = 60,
    min_periods: int = 40,
    clip_val: float = 3.0,
    min_valid_per_day: int = 30,
    use_median: bool = True,
    soft_weights: bool = True,
) -> tuple[pd.DataFrame, pd.DataFrame, pd.DataFrame]:
    """
    Prétraitement CAUSAL (dates x tickers) pour KAN/PCA.
    Retourne:
      X_df: z-score 60j -> de-mean par date -> clip [-clip_val, +clip_val]
      W_df: poids soft 0..1 (ou mask binaire en float si soft_weights=False)
      M_df: mask dur 0/1 (uint8)
    """
    df = log_returns_df.sort_index().copy()

    # 1) Rolling z-score causal (pas de center, pas d'info future)
    mu  = df.rolling(win, min_periods=min_periods).mean()
    sig = df.rolling(win, min_periods=min_periods).std(ddof=0)
    z = (df - mu) / sig

    # Mask dur: z défini ET sigma>0
    M_df = (z.notna()) & (sig.gt(0))

    # 2) De-mean cross-sectionnel (médiane robuste par défaut)
    center = z.median(axis=1) if use_median else z.mean(axis=1)
    z_dm = z.sub(center, axis=0)

    # 3) Clip dans [-clip_val, +clip_val]
    X_df = z_dm.clip(-clip_val, clip_val)

    # 4) Poids soft de fiabilité (0..1) selon taille de fenêtre disponible
    if soft_weights:
        cnt = df.rolling(win, min_periods=1).count()  # 1..win
        denom = max(1, win - min_periods)             # ex: 20 si 60/40
        rel = ((cnt - min_periods) / denom).clip(lower=0.0, upper=1.0)
        W_df = (M_df.astype(float) * rel).astype(float)
    else:
        W_df = M_df.astype(float)

    # 5) Filtrer les dates trop creuses
    keep = M_df.sum(axis=1) >= int(min_valid_per_day)
    X_df = X_df.loc[keep]
    M_df = M_df.loc[keep]
    W_df = W_df.loc[keep]

    # 6) Fill NA après avoir figé le mask/poids
    X_df = X_df.fillna(0.0)
    W_df = W_df.fillna(0.0)
    M_df = M_df.astype(np.uint8)

    return X_df, W_df, M_df


import matplotlib.pyplot as plt

def plot_training_history(history, hyperparameters):
    # Create a figure with 2 rows and 2 columns of subplots
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 10))

    # Plot training and validation loss
    ax1.plot(history['train_loss'], label='Train Loss')
    ax1.plot(history['val_loss'], label='Validation Loss') 
    ax1.set_title('Training and Validation Loss')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Loss')
    ax1.legend()
    ax1.grid(True)

    # Plot regularization loss
    ax2.plot(history['regularization'])
    ax2.set_title('Regularization Loss')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Loss')
    ax2.grid(True)

    # Plot skip gains - either global skip gain or KAN layer skip gains
    if 'skip_gain' in history and history['skip_gain']:
        ax3.plot(history['skip_gain'], color='red')
        ax3.set_title('Global Skip Gain Evolution')
        ax3.set_xlabel('Epoch')
        ax3.set_ylabel('Skip Gain')
    else:
        # Plot KAN encoder and decoder skip gains
        if 'kan_encoder_skip_gains' in history and history['kan_encoder_skip_gains']:
            encoder_gains = history['kan_encoder_skip_gains']
            for i in range(len(encoder_gains[0])):
                gains = [epoch_gains[i] for epoch_gains in encoder_gains]
                ax3.plot(gains, label=f'Encoder Layer {i+1}', linestyle='-')
        
        if 'kan_decoder_skip_gains' in history and history['kan_decoder_skip_gains']:
            decoder_gains = history['kan_decoder_skip_gains']
            for i in range(len(decoder_gains[0])):
                gains = [epoch_gains[i] for epoch_gains in decoder_gains]
                ax3.plot(gains, label=f'Decoder Layer {i+1}', linestyle='--')
                
        ax3.set_title('KAN Layer Skip Gains Evolution')
        ax3.set_xlabel('Epoch')
        ax3.set_ylabel('Skip Gain')
        ax3.legend()
    ax3.grid(True)

    # Plot skip weight norm
    ax4.plot(history['skip_weight_norm'])
    ax4.set_title('Skip Weight Norm')
    ax4.set_xlabel('Epoch')
    ax4.set_ylabel('Weight Norm')
    ax4.grid(True)

    plt.tight_layout()
    plt.show()
    
    # Add hyperparameters as text on the figure
    hyperparams_text = "\n".join([
        f"{k}: {v}" for k, v in hyperparameters.items()
    ])
    
    # Add text box with hyperparameters
    fig.text(1.02, 0.5, hyperparams_text, 
             bbox=dict(facecolor='white', alpha=0.8),
             fontsize=8, 
             transform=plt.gcf().transFigure,
             verticalalignment='center')
    
    plt.subplots_adjust(right=0.85)
    from datetime import datetime
    
    timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
    fig.savefig(f'../figures/training_history_{timestamp}.png',
                bbox_inches='tight', 
                dpi=300)
    
    
def generate_grid_for_sector(X_df, sector):
    hyperparameters_grid = {
    'input_dim': X_df[sector].shape[1],
    'hidden_dims_choices': [
        [128, 64],
        [256, 128, 64], 
        [512, 256, 128, 64]
    ],
    'latent_dims': [8, 16, 32], # bottleneck

    # Architecture KAN
    'basis_types': ["spline", "poly"],
    'M_values': [8, 16, 32],
    'poly_degrees': [3, 5, 7],

    # Activation et régularisation
    'use_silu_choices': [True, False],  # SiLU vs Identity
    'dropout_rates': [0.0, 0.1, 0.2],

    # Skip connections
    'use_global_skip': [True, False],
    'use_skip_choices': [True, False],  # Skip par couche
    'skip_init_choices': ["zeros", "identity", "xavier"],
    'skip_gain_values': [0.1, 0.5, 1.0],

    # Régularisations
    'lambda_reg_values': [0.0, 1e-4, 1e-3],
    'lambda_alpha_values': [0.0, 1e-4, 1e-3],  # L1 sur alpha
    'lambda_group_values': [0.0, 1e-5, 1e-4],  # Group lasso sur c
    'lambda_tv_values': [0.0, 1e-4, 1e-3],  # Total variation sur c (splines)
    'lambda_poly_decay_values': [0.0, 0.1, 1.0],  # Décroissance polynomiale (poly)
    'lambda_skip_l2_values': [0.0, 1e-3, 1e-2],  # L2 sur skip

    # Loss
    'loss_types': ["mse", "huber"], 
    'huber_deltas': [0.1, 0.5, 1.0],

    # Optimisation du training
    'learning_rates': [1e-4, 5e-4, 1e-3],
    'weight_decays': [1e-5, 1e-4],
    'batch_sizes': [32, 64, 128, 256]
}
    return hyperparameters_grid


def sample_and_train(hyperparameters_grid, X_train, X_test, device='cuda', epochs=100):
    import random
    
    sampled_params = {}
    for param_name, param_values in hyperparameters_grid.items():
        if isinstance(param_values, list):
            sampled_params[param_name] = random.choice(param_values)
        else:
            sampled_params[param_name] = param_values
            
    return sampled_params

def evaluate_model(model, X_test, device):
    model.eval()
    with torch.no_grad():
        X_test_recon = model(X_test)
        test_loss = model.loss_fn(X_test_recon, X_test).item()
        print(f"Test loss: {test_loss:.4f}")
        
        
def train_kan_model(hyperparameters, X_train, X_test, device='cuda', epochs=100):
    # Convert device string to torch.device
    device = torch.device(device)
    
    # Move data to device
    X_train = X_train.to(device)
    X_test = X_test.to(device)
    
    model = KANAutoencoder(
        input_dim=hyperparameters['input_dim'],
        hidden_dims=hyperparameters['hidden_dims_choices'],
        k=hyperparameters['latent_dims'],
        basis_type=hyperparameters['basis_types'],
        M=hyperparameters['M_values'],
        poly_degree=hyperparameters['poly_degrees'],
        use_silu=hyperparameters['use_silu_choices'],
        dropout_p=hyperparameters['dropout_rates'],
        use_global_skip=hyperparameters['use_global_skip'],
        use_skip=hyperparameters['use_skip_choices'],
        skip_init=hyperparameters['skip_init_choices'],
        skip_gain=hyperparameters['skip_gain_values'],
        lambda_alpha=hyperparameters['lambda_alpha_values'],
        lambda_group=hyperparameters['lambda_group_values'],
        lambda_tv=hyperparameters['lambda_tv_values'],
        lambda_poly_decay=hyperparameters['lambda_poly_decay_values'],
        lambda_skip_l2=hyperparameters['lambda_skip_l2_values'],
        loss_type=hyperparameters['loss_types'],
        huber_delta=hyperparameters['huber_deltas']
        
    ).to(device)
    
    history = model.fit(X_train,
            epochs=epochs,
            batch_size=hyperparameters['batch_sizes'],
            learning_rate=hyperparameters['learning_rates'],
            weight_decay=hyperparameters['weight_decays'],
            validation_split=0.2,
            patience=15,
            verbose=True,
            lambda_reg=hyperparameters['lambda_reg_values'],
            device=device
            )
    plot_training_history(history, hyperparameters)
    print(f"Training time: {history['training_time']:.2f} seconds")
    evaluate_model(model, X_test, device)

# %%
# Generate datasets 

X_df = {}
W_df = {}
M_df = {}

for sector in sector_log_returns:
    X_df[sector], W_df[sector], M_df[sector] = preprocessing_dataset(
        log_returns_df=sector_log_returns[sector],
        win=60,
        min_periods=40,
        clip_val=3.0,
        min_valid_per_day=5,
        use_median=True,
        soft_weights=True
    )

# %%
# Generate X_sector, W_sector and M_sector

chosen_sector = "information_technology"
X_sector = X_df[chosen_sector]
W_sector = W_df[chosen_sector] 
M_sector = M_df[chosen_sector]

print(f"Secteur choisi: {chosen_sector}")
print(f"Dimensions: {X_df[chosen_sector].shape}")
print(f"Période: {X_df[chosen_sector].index[0]} à {X_df[chosen_sector].index[-1]}")
print("\nStatistiques des données:")
print(f"Moyenne: {X_sector.mean().mean():.4f}")
print(f"Écart-type: {X_sector.std().mean():.4f}")
print(f"Taux de valeurs valides: {M_sector.mean().mean():.2%}")


# Passer en tensor et Train/Test

X_tensor = torch.tensor(X_sector.values, dtype=torch.float32)
W_tensor = torch.tensor(W_sector.values, dtype=torch.float32)
M_tensor = torch.tensor(M_sector.values, dtype=torch.float32)

train_size = int(0.8 * len(X_tensor))
X_train = X_tensor[:train_size]
X_test = X_tensor[train_size:]

W_train = W_tensor[:train_size]
W_test = W_tensor[train_size:]

M_train = M_tensor[:train_size]
M_test = M_tensor[train_size:]

print(f"Train: {X_train.shape[0]} échantillons")
print(f"Test: {X_test.shape[0]} échantillons")
print(f"Dates train: {X_sector.index[0]} à {X_sector.index[train_size-1]}")
print(f"Dates test: {X_sector.index[train_size]} à {X_sector.index[-1]}")
# Out:
# Secteur choisi: information_technology
# Dimensions: (3734, 53)
# Période: 2010-03-03 à 2024-12-31
#
# Statistiques des données:
# Moyenne: 0.0060
# Écart-type: 0.7041
# Taux de valeurs valides: 100.00%
# Train: 2987 échantillons
# Test: 747 échantillons
# Dates train: 2010-03-03 à 2022-01-10
# Dates test: 2022-01-11 à 2024-12-31

# %% [markdown]
# # Hyperparameters grid definition

# %%
# nb_epochs = 20

# hyperparameters_grid = generate_grid_for_sector(X_df, chosen_sector)

# hyperparameters = sample_and_train(hyperparameters_grid, X_train, X_test, epochs=nb_epochs)

# train_kan_model(hyperparameters, X_train, X_test, epochs=nb_epochs)

# %% [markdown]
# # Parameters definition (1 training)

# %%
X_train
# Out:
# tensor([[ 0.1449,  0.1904,  0.2247,  ...,  0.2518, -0.7024, -0.3117],
#         [ 0.2093,  0.6144,  0.1333,  ...,  2.5105,  0.6343, -1.6183],
#         [ 1.3164,  0.1356, -0.1635,  ...,  0.0115, -0.6594, -0.4225],
#         ...,
#         [-1.3219, -3.0000,  0.0000,  ..., -0.7767, -1.5139, -0.4078],
#         [ 0.8888, -0.1851,  0.8853,  ..., -0.4007,  1.5536, -1.0960],
#         [-0.1916,  0.2552,  1.1401,  ..., -0.4892, -0.2731,  0.3610]])

# %%
# ONE TRAINING 

input_dim = X_train.shape[1]
latent_dim = 16
hidden_dims = [32, 16]


epochs = 500
batch_size = 256
learning_rate = 0.0001
weight_decay = 0.00001
validation_split = 0.2
patience = 30
verbose = True

# Basis
basis_type = "spline"
M_value = 16
poly_degree = 5
use_silu = True
xmin = -3.5
xmax = 3.5
dropout_p = 0



# LOSS
loss_type = "huber"
huber_delta = 1.0

# REGULARISATIONS
lambda_reg = 1.0
lambda_alpha = 1e-5
lambda_group = 1e-5
lambda_tv = 1e-5
lambda_poly_decay = 0.0
lambda_skip_l2 = 2e-4

# SKIP
use_global_skip = False

use_skip = True
skip_init = "identity"
skip_gain = 0.6
max_skip_gain = 0.9

# %%
config = {
    'input_dim': input_dim,
    'latent_dim': latent_dim,
    'hidden_dims': hidden_dims,
    'epochs': epochs,
    'batch_size': batch_size,
    'learning_rate': learning_rate,
    'weight_decay': weight_decay,
    'validation_split': validation_split,
    'patience': patience,
    'verbose': verbose,
    'basis_type': basis_type,
    'M_value': M_value,
    'poly_degree': poly_degree,
    'use_silu': use_silu,
    'xmin': xmin,
    'xmax': xmax,
    'dropout_p': dropout_p,
    'loss_type': loss_type,
    'huber_delta': huber_delta,
    'lambda_reg': lambda_reg,
    'lambda_alpha': lambda_alpha,
    'lambda_group': lambda_group,
    'lambda_tv': lambda_tv,
    'lambda_poly_decay': lambda_poly_decay,
    'lambda_skip_l2': lambda_skip_l2,
    'use_global_skip': use_global_skip,
    'use_skip': use_skip,
    'skip_init': skip_init,
    'skip_gain': skip_gain
}

# %% [markdown]
# # KAN Model (1 training)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Device utilisé: {device}")

kan = KANAutoencoder(
    input_dim=input_dim,
    k=latent_dim,
    hidden_dims = hidden_dims,
    basis_type = "spline",
    M = M_value,
    poly_degree = poly_degree,
    xmin = xmin,
    xmax = xmax,
    dropout_p = dropout_p,
    use_silu = use_silu,
    
    # LOSS
    loss_type= loss_type,  
    huber_delta= huber_delta,
    
    # régularisations KAN
    lambda_alpha = lambda_alpha,
    lambda_group = lambda_group,
    lambda_tv = lambda_tv,
    lambda_poly_decay = lambda_poly_decay,
    lambda_skip_l2 = lambda_skip_l2,
    
    # SKIP LINEAIRE
    use_global_skip = use_global_skip,
    use_skip = use_skip,
    skip_init = skip_init,
    skip_gain = skip_gain,
    max_skip_gain = max_skip_gain
)

kan.to(device)

print(f"Nombre total de paramètres: {sum(p.numel() for p in kan.parameters()):,}")
print("Architecture:")
print(f"{input_dim} → {' → '.join(map(str, hidden_dims))} → Latent ({latent_dim}) → {' → '.join(map(str, hidden_dims))} → {input_dim}")
# Out:
# Device utilisé: cuda
# Nombre total de paramètres: 80,169
# Architecture:
# 53 → 32 → 16 → Latent (16) → 32 → 16 → 53

# %%
history = kan.fit(
    X_train,
    epochs=epochs,
    batch_size=batch_size,
    learning_rate=learning_rate,
    weight_decay=weight_decay,
    validation_split=validation_split,
    patience=patience,
    verbose=verbose,
    lambda_reg=lambda_reg
)
# Out:
# 📈 Epoch 1/500 | Train: 0.213516 | Val: 0.219273 ✅ | Reg: 0.033493 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.5991', '0.5991']
#    ↳ KAN decoder skip gains: ['0.5990', '0.5990']
# 📈 Epoch 2/500 | Train: 0.213090 | Val: 0.219247 ✅ | Reg: 0.032245 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.5982', '0.5982']
#    ↳ KAN decoder skip gains: ['0.5981', '0.5981']
# 📈 Epoch 3/500 | Train: 0.212439 | Val: 0.219224 ✅ | Reg: 0.031077 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.5974', '0.5974']
#    ↳ KAN decoder skip gains: ['0.5972', '0.5972']
# 📈 Epoch 4/500 | Train: 0.213450 | Val: 0.219204 ✅ | Reg: 0.029988 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.5968', '0.5968']
#    ↳ KAN decoder skip gains: ['0.5963', '0.5963']
# 📈 Epoch 5/500 | Train: 0.213315 | Val: 0.219187 ✅ | Reg: 0.028977 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.5964', '0.5964']
#    ↳ KAN decoder skip gains: ['0.5955', '0.5955']
# 📈 Epoch 6/500 | Train: 0.213002 | Val: 0.219171 ✅ | Reg: 0.028040 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.5960', '0.5961']
#    ↳ KAN decoder skip gains: ['0.5947', '0.5947']
# 📈 Epoch 7/500 | Train: 0.212334 | Val: 0.219157 ✅ | Reg: 0.027174 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.5958', '0.5960']
#    ↳ KAN decoder skip gains: ['0.5939', '0.5940']
# 📈 Epoch 8/500 | Train: 0.212695 | Val: 0.219145 ✅ | Reg: 0.026375 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.5958', '0.5961']
#    ↳ KAN decoder skip gains: ['0.5933', '0.5934']
# 📈 Epoch 9/500 | Train: 0.214070 | Val: 0.219135 ✅ | Reg: 0.025637 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.5959', '0.5964']
#    ↳ KAN decoder skip gains: ['0.5927', '0.5928']
# 📈 Epoch 10/500 | Train: 0.212792 | Val: 0.219125 ✅ | Reg: 0.024956 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.5961', '0.5968']
#    ↳ KAN decoder skip gains: ['0.5921', '0.5923']
# 📈 Epoch 11/500 | Train: 0.213690 | Val: 0.219117 ✅ | Reg: 0.024348 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.5966', '0.5974']
#    ↳ KAN decoder skip gains: ['0.5917', '0.5918']
# 📈 Epoch 12/500 | Train: 0.213395 | Val: 0.219109 ✅ | Reg: 0.023801 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.5971', '0.5981']
#    ↳ KAN decoder skip gains: ['0.5912', '0.5914']
# 📈 Epoch 13/500 | Train: 0.214214 | Val: 0.219102 ✅ | Reg: 0.023299 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.5979', '0.5992']
#    ↳ KAN decoder skip gains: ['0.5907', '0.5910']
# 📈 Epoch 14/500 | Train: 0.213494 | Val: 0.219095 ✅ | Reg: 0.022835 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.5988', '0.6002']
#    ↳ KAN decoder skip gains: ['0.5904', '0.5907']
# 📈 Epoch 15/500 | Train: 0.213831 | Val: 0.219089 ✅ | Reg: 0.022406 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.5998', '0.6014']
#    ↳ KAN decoder skip gains: ['0.5900', '0.5904']
# 📈 Epoch 16/500 | Train: 0.213525 | Val: 0.219084 ✅ | Reg: 0.022006 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6009', '0.6026']
#    ↳ KAN decoder skip gains: ['0.5897', '0.5901']
# 📈 Epoch 17/500 | Train: 0.213132 | Val: 0.219079 ✅ | Reg: 0.021633 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6021', '0.6040']
#    ↳ KAN decoder skip gains: ['0.5894', '0.5899']
# 📈 Epoch 18/500 | Train: 0.213655 | Val: 0.219073 ✅ | Reg: 0.021283 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6034', '0.6053']
#    ↳ KAN decoder skip gains: ['0.5892', '0.5898']
# 📈 Epoch 19/500 | Train: 0.213224 | Val: 0.219069 ✅ | Reg: 0.020954 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6046', '0.6067']
#    ↳ KAN decoder skip gains: ['0.5890', '0.5896']
# 📈 Epoch 20/500 | Train: 0.213331 | Val: 0.219065 ✅ | Reg: 0.020643 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6060', '0.6081']
#    ↳ KAN decoder skip gains: ['0.5888', '0.5895']
# 📈 Epoch 21/500 | Train: 0.214454 | Val: 0.219061 ✅ | Reg: 0.020349 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6074', '0.6096']
#    ↳ KAN decoder skip gains: ['0.5887', '0.5895']
# 📈 Epoch 22/500 | Train: 0.213570 | Val: 0.219058 ✅ | Reg: 0.020069 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6088', '0.6111']
#    ↳ KAN decoder skip gains: ['0.5887', '0.5895']
# 📈 Epoch 23/500 | Train: 0.213305 | Val: 0.219054 ✅ | Reg: 0.019802 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6103', '0.6126']
#    ↳ KAN decoder skip gains: ['0.5886', '0.5895']
# 📈 Epoch 24/500 | Train: 0.212553 | Val: 0.219051 ✅ | Reg: 0.019549 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6118', '0.6142']
#    ↳ KAN decoder skip gains: ['0.5887', '0.5896']
# 📈 Epoch 25/500 | Train: 0.212980 | Val: 0.219047 ✅ | Reg: 0.019305 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6133', '0.6157']
#    ↳ KAN decoder skip gains: ['0.5888', '0.5898']
# 📈 Epoch 26/500 | Train: 0.213302 | Val: 0.219044 ✅ | Reg: 0.019072 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6148', '0.6172']
#    ↳ KAN decoder skip gains: ['0.5889', '0.5900']
# 📈 Epoch 27/500 | Train: 0.212537 | Val: 0.219041 ✅ | Reg: 0.018847 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6163', '0.6188']
#    ↳ KAN decoder skip gains: ['0.5891', '0.5903']
# 📈 Epoch 28/500 | Train: 0.212547 | Val: 0.219037 ✅ | Reg: 0.018629 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6178', '0.6203']
#    ↳ KAN decoder skip gains: ['0.5894', '0.5906']
# 📈 Epoch 29/500 | Train: 0.213969 | Val: 0.219034 ✅ | Reg: 0.018418 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6193', '0.6219']
#    ↳ KAN decoder skip gains: ['0.5896', '0.5909']
# 📈 Epoch 30/500 | Train: 0.212701 | Val: 0.219031 ✅ | Reg: 0.018213 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6209', '0.6235']
#    ↳ KAN decoder skip gains: ['0.5899', '0.5913']
# 📈 Epoch 31/500 | Train: 0.213383 | Val: 0.219028 ✅ | Reg: 0.018013 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6224', '0.6250']
#    ↳ KAN decoder skip gains: ['0.5903', '0.5917']
# 📈 Epoch 32/500 | Train: 0.215456 | Val: 0.219025 ✅ | Reg: 0.017817 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6240', '0.6266']
#    ↳ KAN decoder skip gains: ['0.5906', '0.5922']
# 📈 Epoch 33/500 | Train: 0.212106 | Val: 0.219021 ✅ | Reg: 0.017626 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6255', '0.6281']
#    ↳ KAN decoder skip gains: ['0.5911', '0.5927']
# 📈 Epoch 34/500 | Train: 0.212993 | Val: 0.219018 ✅ | Reg: 0.017438 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6271', '0.6297']
#    ↳ KAN decoder skip gains: ['0.5915', '0.5932']
# 📈 Epoch 35/500 | Train: 0.212579 | Val: 0.219015 ✅ | Reg: 0.017254 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6286', '0.6312']
#    ↳ KAN decoder skip gains: ['0.5919', '0.5937']
# 📈 Epoch 36/500 | Train: 0.212933 | Val: 0.219012 ✅ | Reg: 0.017072 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6301', '0.6327']
#    ↳ KAN decoder skip gains: ['0.5925', '0.5943']
# 📈 Epoch 37/500 | Train: 0.213298 | Val: 0.219009 ✅ | Reg: 0.016893 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6316', '0.6343']
#    ↳ KAN decoder skip gains: ['0.5931', '0.5950']
# 📈 Epoch 38/500 | Train: 0.211576 | Val: 0.219005 ✅ | Reg: 0.016717 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6332', '0.6358']
#    ↳ KAN decoder skip gains: ['0.5937', '0.5957']
# 📈 Epoch 39/500 | Train: 0.212704 | Val: 0.219001 ✅ | Reg: 0.016544 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6348', '0.6374']
#    ↳ KAN decoder skip gains: ['0.5944', '0.5965']
# 📈 Epoch 40/500 | Train: 0.213075 | Val: 0.218998 ✅ | Reg: 0.016373 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6364', '0.6390']
#    ↳ KAN decoder skip gains: ['0.5951', '0.5972']
# 📈 Epoch 41/500 | Train: 0.212682 | Val: 0.218994 ✅ | Reg: 0.016204 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6379', '0.6406']
#    ↳ KAN decoder skip gains: ['0.5958', '0.5980']
# 📈 Epoch 42/500 | Train: 0.212821 | Val: 0.218989 ✅ | Reg: 0.016037 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6396', '0.6422']
#    ↳ KAN decoder skip gains: ['0.5966', '0.5989']
# 📈 Epoch 43/500 | Train: 0.212907 | Val: 0.218985 ✅ | Reg: 0.015872 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6411', '0.6438']
#    ↳ KAN decoder skip gains: ['0.5974', '0.5998']
# 📈 Epoch 44/500 | Train: 0.213162 | Val: 0.218980 ✅ | Reg: 0.015709 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6428', '0.6454']
#    ↳ KAN decoder skip gains: ['0.5983', '0.6007']
# 📈 Epoch 45/500 | Train: 0.213426 | Val: 0.218976 ✅ | Reg: 0.015548 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6444', '0.6471']
#    ↳ KAN decoder skip gains: ['0.5992', '0.6017']
# 📈 Epoch 46/500 | Train: 0.213042 | Val: 0.218970 ✅ | Reg: 0.015389 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6461', '0.6487']
#    ↳ KAN decoder skip gains: ['0.6002', '0.6027']
# 📈 Epoch 47/500 | Train: 0.213239 | Val: 0.218964 ✅ | Reg: 0.015231 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6477', '0.6504']
#    ↳ KAN decoder skip gains: ['0.6011', '0.6038']
# 📈 Epoch 48/500 | Train: 0.214459 | Val: 0.218958 ✅ | Reg: 0.015076 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6494', '0.6520']
#    ↳ KAN decoder skip gains: ['0.6021', '0.6048']
# 📈 Epoch 49/500 | Train: 0.212030 | Val: 0.218950 ✅ | Reg: 0.014922 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6511', '0.6537']
#    ↳ KAN decoder skip gains: ['0.6032', '0.6060']
# 📈 Epoch 50/500 | Train: 0.212624 | Val: 0.218943 ✅ | Reg: 0.014770 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6528', '0.6554']
#    ↳ KAN decoder skip gains: ['0.6043', '0.6071']
# 📈 Epoch 51/500 | Train: 0.214041 | Val: 0.218934 ✅ | Reg: 0.014620 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6545', '0.6572']
#    ↳ KAN decoder skip gains: ['0.6055', '0.6083']
# 📈 Epoch 52/500 | Train: 0.213444 | Val: 0.218925 ✅ | Reg: 0.014471 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6563', '0.6589']
#    ↳ KAN decoder skip gains: ['0.6066', '0.6096']
# 📈 Epoch 53/500 | Train: 0.212180 | Val: 0.218915 ✅ | Reg: 0.014325 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6580', '0.6606']
#    ↳ KAN decoder skip gains: ['0.6079', '0.6109']
# 📈 Epoch 54/500 | Train: 0.213579 | Val: 0.218903 ✅ | Reg: 0.014180 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6598', '0.6624']
#    ↳ KAN decoder skip gains: ['0.6092', '0.6122']
# 📈 Epoch 55/500 | Train: 0.212707 | Val: 0.218890 ✅ | Reg: 0.014037 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6616', '0.6642']
#    ↳ KAN decoder skip gains: ['0.6105', '0.6136']
# 📈 Epoch 56/500 | Train: 0.213249 | Val: 0.218877 ✅ | Reg: 0.013895 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6634', '0.6660']
#    ↳ KAN decoder skip gains: ['0.6119', '0.6150']
# 📈 Epoch 57/500 | Train: 0.212104 | Val: 0.218862 ✅ | Reg: 0.013756 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6653', '0.6679']
#    ↳ KAN decoder skip gains: ['0.6134', '0.6166']
# 📈 Epoch 58/500 | Train: 0.213797 | Val: 0.218845 ✅ | Reg: 0.013619 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6671', '0.6698']
#    ↳ KAN decoder skip gains: ['0.6149', '0.6181']
# 📈 Epoch 59/500 | Train: 0.212882 | Val: 0.218826 ✅ | Reg: 0.013483 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6691', '0.6717']
#    ↳ KAN decoder skip gains: ['0.6165', '0.6197']
# 📈 Epoch 60/500 | Train: 0.212212 | Val: 0.218805 ✅ | Reg: 0.013350 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6710', '0.6736']
#    ↳ KAN decoder skip gains: ['0.6181', '0.6214']
# 📈 Epoch 61/500 | Train: 0.211767 | Val: 0.218782 ✅ | Reg: 0.013219 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6730', '0.6756']
#    ↳ KAN decoder skip gains: ['0.6198', '0.6231']
# 📈 Epoch 62/500 | Train: 0.214342 | Val: 0.218756 ✅ | Reg: 0.013089 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6750', '0.6776']
#    ↳ KAN decoder skip gains: ['0.6215', '0.6248']
# 📈 Epoch 63/500 | Train: 0.213564 | Val: 0.218723 ✅ | Reg: 0.012962 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6771', '0.6797']
#    ↳ KAN decoder skip gains: ['0.6233', '0.6267']
# 📈 Epoch 64/500 | Train: 0.212511 | Val: 0.218688 ✅ | Reg: 0.012838 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6792', '0.6818']
#    ↳ KAN decoder skip gains: ['0.6251', '0.6285']
# 📈 Epoch 65/500 | Train: 0.212252 | Val: 0.218648 ✅ | Reg: 0.012716 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6814', '0.6840']
#    ↳ KAN decoder skip gains: ['0.6270', '0.6305']
# 📈 Epoch 66/500 | Train: 0.213168 | Val: 0.218598 ✅ | Reg: 0.012597 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6836', '0.6862']
#    ↳ KAN decoder skip gains: ['0.6290', '0.6325']
# 📈 Epoch 67/500 | Train: 0.212955 | Val: 0.218542 ✅ | Reg: 0.012481 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6859', '0.6885']
#    ↳ KAN decoder skip gains: ['0.6311', '0.6346']
# 📈 Epoch 68/500 | Train: 0.211787 | Val: 0.218473 ✅ | Reg: 0.012368 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6883', '0.6909']
#    ↳ KAN decoder skip gains: ['0.6333', '0.6369']
# 📈 Epoch 69/500 | Train: 0.212106 | Val: 0.218390 ✅ | Reg: 0.012259 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6908', '0.6934']
#    ↳ KAN decoder skip gains: ['0.6357', '0.6392']
# 📈 Epoch 70/500 | Train: 0.213066 | Val: 0.218289 ✅ | Reg: 0.012155 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6934', '0.6960']
#    ↳ KAN decoder skip gains: ['0.6381', '0.6417']
# 📈 Epoch 71/500 | Train: 0.212428 | Val: 0.218170 ✅ | Reg: 0.012055 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6960', '0.6986']
#    ↳ KAN decoder skip gains: ['0.6406', '0.6442']
# 📈 Epoch 72/500 | Train: 0.212943 | Val: 0.218015 ✅ | Reg: 0.011960 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.6988', '0.7014']
#    ↳ KAN decoder skip gains: ['0.6433', '0.6469']
# 📈 Epoch 73/500 | Train: 0.212137 | Val: 0.217826 ✅ | Reg: 0.011872 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7017', '0.7043']
#    ↳ KAN decoder skip gains: ['0.6461', '0.6498']
# 📈 Epoch 74/500 | Train: 0.211819 | Val: 0.217598 ✅ | Reg: 0.011790 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7047', '0.7073']
#    ↳ KAN decoder skip gains: ['0.6490', '0.6527']
# 📈 Epoch 75/500 | Train: 0.212844 | Val: 0.217309 ✅ | Reg: 0.011715 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7078', '0.7104']
#    ↳ KAN decoder skip gains: ['0.6521', '0.6557']
# 📈 Epoch 76/500 | Train: 0.210476 | Val: 0.216936 ✅ | Reg: 0.011650 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7110', '0.7137']
#    ↳ KAN decoder skip gains: ['0.6553', '0.6589']
# 📈 Epoch 77/500 | Train: 0.210716 | Val: 0.216475 ✅ | Reg: 0.011595 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7143', '0.7170']
#    ↳ KAN decoder skip gains: ['0.6585', '0.6622']
# 📈 Epoch 78/500 | Train: 0.210275 | Val: 0.215897 ✅ | Reg: 0.011551 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7177', '0.7204']
#    ↳ KAN decoder skip gains: ['0.6619', '0.6656']
# 📈 Epoch 79/500 | Train: 0.208693 | Val: 0.215177 ✅ | Reg: 0.011518 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7212', '0.7239']
#    ↳ KAN decoder skip gains: ['0.6654', '0.6691']
# 📈 Epoch 80/500 | Train: 0.209318 | Val: 0.214300 ✅ | Reg: 0.011498 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7248', '0.7275']
#    ↳ KAN decoder skip gains: ['0.6690', '0.6727']
# 📈 Epoch 81/500 | Train: 0.209878 | Val: 0.213236 ✅ | Reg: 0.011491 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7284', '0.7311']
#    ↳ KAN decoder skip gains: ['0.6726', '0.6763']
# 📈 Epoch 82/500 | Train: 0.207089 | Val: 0.212004 ✅ | Reg: 0.011498 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7320', '0.7347']
#    ↳ KAN decoder skip gains: ['0.6762', '0.6799']
# 📈 Epoch 83/500 | Train: 0.205491 | Val: 0.210668 ✅ | Reg: 0.011514 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7354', '0.7382']
#    ↳ KAN decoder skip gains: ['0.6797', '0.6835']
# 📈 Epoch 84/500 | Train: 0.202900 | Val: 0.209270 ✅ | Reg: 0.011539 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7388', '0.7416']
#    ↳ KAN decoder skip gains: ['0.6831', '0.6869']
# 📈 Epoch 85/500 | Train: 0.203388 | Val: 0.207998 ✅ | Reg: 0.011565 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7419', '0.7447']
#    ↳ KAN decoder skip gains: ['0.6862', '0.6901']
# 📈 Epoch 86/500 | Train: 0.201935 | Val: 0.206944 ✅ | Reg: 0.011584 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7446', '0.7475']
#    ↳ KAN decoder skip gains: ['0.6890', '0.6929']
# 📈 Epoch 87/500 | Train: 0.200865 | Val: 0.206156 ✅ | Reg: 0.011587 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7469', '0.7498']
#    ↳ KAN decoder skip gains: ['0.6913', '0.6953']
# 📈 Epoch 88/500 | Train: 0.201068 | Val: 0.205601 ✅ | Reg: 0.011564 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7484', '0.7514']
#    ↳ KAN decoder skip gains: ['0.6930', '0.6970']
# 📈 Epoch 89/500 | Train: 0.199262 | Val: 0.205200 ✅ | Reg: 0.011515 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7495', '0.7525']
#    ↳ KAN decoder skip gains: ['0.6942', '0.6983']
# 📈 Epoch 90/500 | Train: 0.199034 | Val: 0.204878 ✅ | Reg: 0.011446 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7501', '0.7533']
#    ↳ KAN decoder skip gains: ['0.6950', '0.6992']
# 📈 Epoch 91/500 | Train: 0.200147 | Val: 0.204618 ✅ | Reg: 0.011367 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7506', '0.7539']
#    ↳ KAN decoder skip gains: ['0.6956', '0.7000']
# 📈 Epoch 92/500 | Train: 0.198556 | Val: 0.204398 ✅ | Reg: 0.011283 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7511', '0.7545']
#    ↳ KAN decoder skip gains: ['0.6962', '0.7007']
# 📈 Epoch 93/500 | Train: 0.199835 | Val: 0.204216 ✅ | Reg: 0.011199 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7515', '0.7550']
#    ↳ KAN decoder skip gains: ['0.6967', '0.7013']
# 📈 Epoch 94/500 | Train: 0.199595 | Val: 0.204061 ✅ | Reg: 0.011114 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7519', '0.7555']
#    ↳ KAN decoder skip gains: ['0.6972', '0.7020']
# 📈 Epoch 95/500 | Train: 0.198791 | Val: 0.203919 ✅ | Reg: 0.011031 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7524', '0.7560']
#    ↳ KAN decoder skip gains: ['0.6978', '0.7027']
# 📈 Epoch 96/500 | Train: 0.197296 | Val: 0.203801 ✅ | Reg: 0.010948 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7528', '0.7565']
#    ↳ KAN decoder skip gains: ['0.6983', '0.7033']
# 📈 Epoch 97/500 | Train: 0.197602 | Val: 0.203695 ✅ | Reg: 0.010865 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7532', '0.7570']
#    ↳ KAN decoder skip gains: ['0.6988', '0.7039']
# 📈 Epoch 98/500 | Train: 0.197267 | Val: 0.203602 ✅ | Reg: 0.010781 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7536', '0.7575']
#    ↳ KAN decoder skip gains: ['0.6993', '0.7045']
# 📈 Epoch 99/500 | Train: 0.197112 | Val: 0.203519 ✅ | Reg: 0.010700 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7540', '0.7580']
#    ↳ KAN decoder skip gains: ['0.6998', '0.7051']
# 📈 Epoch 100/500 | Train: 0.197887 | Val: 0.203443 ✅ | Reg: 0.010619 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7545', '0.7585']
#    ↳ KAN decoder skip gains: ['0.7003', '0.7057']
# 📈 Epoch 101/500 | Train: 0.198904 | Val: 0.203371 ✅ | Reg: 0.010538 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7549', '0.7590']
#    ↳ KAN decoder skip gains: ['0.7008', '0.7063']
# 📈 Epoch 102/500 | Train: 0.197650 | Val: 0.203313 ✅ | Reg: 0.010457 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7552', '0.7594']
#    ↳ KAN decoder skip gains: ['0.7013', '0.7068']
# 📈 Epoch 103/500 | Train: 0.196801 | Val: 0.203260 ✅ | Reg: 0.010375 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7556', '0.7599']
#    ↳ KAN decoder skip gains: ['0.7017', '0.7074']
# 📈 Epoch 104/500 | Train: 0.196791 | Val: 0.203212 ✅ | Reg: 0.010293 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7560', '0.7603']
#    ↳ KAN decoder skip gains: ['0.7021', '0.7078']
# 📈 Epoch 105/500 | Train: 0.197665 | Val: 0.203166 ✅ | Reg: 0.010212 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7564', '0.7607']
#    ↳ KAN decoder skip gains: ['0.7026', '0.7084']
# 📈 Epoch 106/500 | Train: 0.197439 | Val: 0.203120 ✅ | Reg: 0.010134 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7568', '0.7612']
#    ↳ KAN decoder skip gains: ['0.7031', '0.7089']
# 📈 Epoch 107/500 | Train: 0.197247 | Val: 0.203073 ✅ | Reg: 0.010058 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7573', '0.7617']
#    ↳ KAN decoder skip gains: ['0.7036', '0.7095']
# 📈 Epoch 108/500 | Train: 0.197320 | Val: 0.203025 ✅ | Reg: 0.009982 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7577', '0.7622']
#    ↳ KAN decoder skip gains: ['0.7042', '0.7101']
# 📈 Epoch 109/500 | Train: 0.197264 | Val: 0.202985 ✅ | Reg: 0.009905 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7581', '0.7627']
#    ↳ KAN decoder skip gains: ['0.7046', '0.7106']
# 📈 Epoch 110/500 | Train: 0.198335 | Val: 0.202951 ✅ | Reg: 0.009829 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7585', '0.7631']
#    ↳ KAN decoder skip gains: ['0.7051', '0.7111']
# 📈 Epoch 111/500 | Train: 0.197462 | Val: 0.202921 ✅ | Reg: 0.009752 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7589', '0.7636']
#    ↳ KAN decoder skip gains: ['0.7055', '0.7115']
# 📈 Epoch 112/500 | Train: 0.197076 | Val: 0.202888 ✅ | Reg: 0.009677 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7594', '0.7641']
#    ↳ KAN decoder skip gains: ['0.7060', '0.7121']
# 📈 Epoch 113/500 | Train: 0.197542 | Val: 0.202858 ✅ | Reg: 0.009604 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7599', '0.7646']
#    ↳ KAN decoder skip gains: ['0.7066', '0.7126']
# 📈 Epoch 114/500 | Train: 0.195923 | Val: 0.202829 ✅ | Reg: 0.009531 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7603', '0.7651']
#    ↳ KAN decoder skip gains: ['0.7071', '0.7132']
# 📈 Epoch 115/500 | Train: 0.196842 | Val: 0.202802 ✅ | Reg: 0.009460 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7608', '0.7656']
#    ↳ KAN decoder skip gains: ['0.7076', '0.7137']
# 📈 Epoch 116/500 | Train: 0.197476 | Val: 0.202775 ✅ | Reg: 0.009388 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7612', '0.7661']
#    ↳ KAN decoder skip gains: ['0.7081', '0.7142']
# 📈 Epoch 117/500 | Train: 0.196488 | Val: 0.202750 ✅ | Reg: 0.009317 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7617', '0.7666']
#    ↳ KAN decoder skip gains: ['0.7085', '0.7147']
# 📈 Epoch 118/500 | Train: 0.196228 | Val: 0.202723 ✅ | Reg: 0.009246 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7622', '0.7671']
#    ↳ KAN decoder skip gains: ['0.7090', '0.7152']
# 📈 Epoch 119/500 | Train: 0.197257 | Val: 0.202698 ✅ | Reg: 0.009176 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7626', '0.7676']
#    ↳ KAN decoder skip gains: ['0.7096', '0.7157']
# 📈 Epoch 120/500 | Train: 0.197571 | Val: 0.202675 ✅ | Reg: 0.009107 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7631', '0.7681']
#    ↳ KAN decoder skip gains: ['0.7101', '0.7162']
# 📈 Epoch 121/500 | Train: 0.197555 | Val: 0.202650 ✅ | Reg: 0.009039 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7637', '0.7687']
#    ↳ KAN decoder skip gains: ['0.7107', '0.7168']
# 📈 Epoch 122/500 | Train: 0.196989 | Val: 0.202628 ✅ | Reg: 0.008973 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7642', '0.7693']
#    ↳ KAN decoder skip gains: ['0.7112', '0.7173']
# 📈 Epoch 123/500 | Train: 0.196684 | Val: 0.202601 ✅ | Reg: 0.008908 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7647', '0.7698']
#    ↳ KAN decoder skip gains: ['0.7118', '0.7178']
# 📈 Epoch 124/500 | Train: 0.197535 | Val: 0.202574 ✅ | Reg: 0.008842 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7652', '0.7703']
#    ↳ KAN decoder skip gains: ['0.7123', '0.7183']
# 📈 Epoch 125/500 | Train: 0.197200 | Val: 0.202552 ✅ | Reg: 0.008775 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7657', '0.7708']
#    ↳ KAN decoder skip gains: ['0.7128', '0.7188']
# 📈 Epoch 126/500 | Train: 0.196861 | Val: 0.202534 ✅ | Reg: 0.008710 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7662', '0.7714']
#    ↳ KAN decoder skip gains: ['0.7133', '0.7194']
# 📈 Epoch 127/500 | Train: 0.197230 | Val: 0.202508 ✅ | Reg: 0.008648 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7668', '0.7720']
#    ↳ KAN decoder skip gains: ['0.7140', '0.7200']
# 📈 Epoch 128/500 | Train: 0.197012 | Val: 0.202485 ✅ | Reg: 0.008587 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7674', '0.7726']
#    ↳ KAN decoder skip gains: ['0.7145', '0.7205']
# 📈 Epoch 129/500 | Train: 0.196542 | Val: 0.202461 ✅ | Reg: 0.008526 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7679', '0.7732']
#    ↳ KAN decoder skip gains: ['0.7151', '0.7211']
# 📈 Epoch 130/500 | Train: 0.196793 | Val: 0.202437 ✅ | Reg: 0.008464 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7685', '0.7737']
#    ↳ KAN decoder skip gains: ['0.7157', '0.7216']
# 📈 Epoch 131/500 | Train: 0.197289 | Val: 0.202408 ✅ | Reg: 0.008403 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7690', '0.7743']
#    ↳ KAN decoder skip gains: ['0.7163', '0.7221']
# 📈 Epoch 132/500 | Train: 0.195800 | Val: 0.202386 ✅ | Reg: 0.008344 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7696', '0.7749']
#    ↳ KAN decoder skip gains: ['0.7168', '0.7227']
# 📈 Epoch 133/500 | Train: 0.196742 | Val: 0.202360 ✅ | Reg: 0.008286 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7702', '0.7755']
#    ↳ KAN decoder skip gains: ['0.7175', '0.7233']
# 📈 Epoch 134/500 | Train: 0.197054 | Val: 0.202332 ✅ | Reg: 0.008229 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7708', '0.7761']
#    ↳ KAN decoder skip gains: ['0.7181', '0.7239']
# 📈 Epoch 135/500 | Train: 0.197651 | Val: 0.202303 ✅ | Reg: 0.008173 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7714', '0.7768']
#    ↳ KAN decoder skip gains: ['0.7187', '0.7245']
# 📈 Epoch 136/500 | Train: 0.196780 | Val: 0.202271 ✅ | Reg: 0.008117 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7721', '0.7774']
#    ↳ KAN decoder skip gains: ['0.7193', '0.7251']
# 📈 Epoch 137/500 | Train: 0.196147 | Val: 0.202237 ✅ | Reg: 0.008063 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7727', '0.7781']
#    ↳ KAN decoder skip gains: ['0.7200', '0.7257']
# 📈 Epoch 138/500 | Train: 0.196435 | Val: 0.202207 ✅ | Reg: 0.008009 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7734', '0.7787']
#    ↳ KAN decoder skip gains: ['0.7206', '0.7263']
# 📈 Epoch 139/500 | Train: 0.196596 | Val: 0.202169 ✅ | Reg: 0.007956 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7740', '0.7794']
#    ↳ KAN decoder skip gains: ['0.7213', '0.7270']
# 📈 Epoch 140/500 | Train: 0.196344 | Val: 0.202129 ✅ | Reg: 0.007906 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7747', '0.7801']
#    ↳ KAN decoder skip gains: ['0.7220', '0.7276']
# 📈 Epoch 141/500 | Train: 0.196088 | Val: 0.202083 ✅ | Reg: 0.007856 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7755', '0.7808']
#    ↳ KAN decoder skip gains: ['0.7228', '0.7283']
# 📈 Epoch 142/500 | Train: 0.196698 | Val: 0.202035 ✅ | Reg: 0.007806 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7761', '0.7815']
#    ↳ KAN decoder skip gains: ['0.7234', '0.7289']
# 📈 Epoch 143/500 | Train: 0.196712 | Val: 0.201977 ✅ | Reg: 0.007758 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7769', '0.7823']
#    ↳ KAN decoder skip gains: ['0.7242', '0.7297']
# 📈 Epoch 144/500 | Train: 0.196990 | Val: 0.201917 ✅ | Reg: 0.007713 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7777', '0.7831']
#    ↳ KAN decoder skip gains: ['0.7250', '0.7304']
# 📈 Epoch 145/500 | Train: 0.195550 | Val: 0.201849 ✅ | Reg: 0.007670 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7785', '0.7839']
#    ↳ KAN decoder skip gains: ['0.7258', '0.7312']
# 📈 Epoch 146/500 | Train: 0.196123 | Val: 0.201775 ✅ | Reg: 0.007626 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7793', '0.7847']
#    ↳ KAN decoder skip gains: ['0.7266', '0.7320']
# 📈 Epoch 147/500 | Train: 0.195787 | Val: 0.201690 ✅ | Reg: 0.007585 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7801', '0.7855']
#    ↳ KAN decoder skip gains: ['0.7274', '0.7328']
# 📈 Epoch 148/500 | Train: 0.195342 | Val: 0.201599 ✅ | Reg: 0.007545 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7810', '0.7864']
#    ↳ KAN decoder skip gains: ['0.7283', '0.7336']
# 📈 Epoch 149/500 | Train: 0.195426 | Val: 0.201500 ✅ | Reg: 0.007508 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7820', '0.7873']
#    ↳ KAN decoder skip gains: ['0.7292', '0.7345']
# 📈 Epoch 150/500 | Train: 0.195986 | Val: 0.201384 ✅ | Reg: 0.007473 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7830', '0.7883']
#    ↳ KAN decoder skip gains: ['0.7302', '0.7354']
# 📈 Epoch 151/500 | Train: 0.195625 | Val: 0.201248 ✅ | Reg: 0.007440 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7840', '0.7893']
#    ↳ KAN decoder skip gains: ['0.7312', '0.7364']
# 📈 Epoch 152/500 | Train: 0.195341 | Val: 0.201094 ✅ | Reg: 0.007409 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7850', '0.7904']
#    ↳ KAN decoder skip gains: ['0.7322', '0.7374']
# 📈 Epoch 153/500 | Train: 0.195428 | Val: 0.200923 ✅ | Reg: 0.007380 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7862', '0.7915']
#    ↳ KAN decoder skip gains: ['0.7333', '0.7385']
# 📈 Epoch 154/500 | Train: 0.195273 | Val: 0.200720 ✅ | Reg: 0.007355 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7874', '0.7927']
#    ↳ KAN decoder skip gains: ['0.7345', '0.7396']
# 📈 Epoch 155/500 | Train: 0.196389 | Val: 0.200491 ✅ | Reg: 0.007334 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7886', '0.7939']
#    ↳ KAN decoder skip gains: ['0.7358', '0.7408']
# 📈 Epoch 156/500 | Train: 0.194340 | Val: 0.200227 ✅ | Reg: 0.007315 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7900', '0.7952']
#    ↳ KAN decoder skip gains: ['0.7371', '0.7421']
# 📈 Epoch 157/500 | Train: 0.195799 | Val: 0.199929 ✅ | Reg: 0.007300 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7913', '0.7966']
#    ↳ KAN decoder skip gains: ['0.7384', '0.7435']
# 📈 Epoch 158/500 | Train: 0.195402 | Val: 0.199588 ✅ | Reg: 0.007287 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7928', '0.7980']
#    ↳ KAN decoder skip gains: ['0.7399', '0.7449']
# 📈 Epoch 159/500 | Train: 0.193903 | Val: 0.199210 ✅ | Reg: 0.007279 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7944', '0.7995']
#    ↳ KAN decoder skip gains: ['0.7414', '0.7464']
# 📈 Epoch 160/500 | Train: 0.193317 | Val: 0.198807 ✅ | Reg: 0.007274 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7959', '0.8011']
#    ↳ KAN decoder skip gains: ['0.7430', '0.7480']
# 📈 Epoch 161/500 | Train: 0.193930 | Val: 0.198361 ✅ | Reg: 0.007271 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7976', '0.8027']
#    ↳ KAN decoder skip gains: ['0.7447', '0.7497']
# 📈 Epoch 162/500 | Train: 0.192965 | Val: 0.197913 ✅ | Reg: 0.007270 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.7992', '0.8043']
#    ↳ KAN decoder skip gains: ['0.7464', '0.7514']
# 📈 Epoch 163/500 | Train: 0.191128 | Val: 0.197476 ✅ | Reg: 0.007268 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8007', '0.8058']
#    ↳ KAN decoder skip gains: ['0.7480', '0.7530']
# 📈 Epoch 164/500 | Train: 0.190877 | Val: 0.197056 ✅ | Reg: 0.007263 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8021', '0.8072']
#    ↳ KAN decoder skip gains: ['0.7496', '0.7546']
# 📈 Epoch 165/500 | Train: 0.191596 | Val: 0.196653 ✅ | Reg: 0.007260 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8036', '0.8087']
#    ↳ KAN decoder skip gains: ['0.7512', '0.7563']
# 📈 Epoch 166/500 | Train: 0.190896 | Val: 0.196285 ✅ | Reg: 0.007254 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8049', '0.8100']
#    ↳ KAN decoder skip gains: ['0.7527', '0.7579']
# 📈 Epoch 167/500 | Train: 0.191343 | Val: 0.195957 ✅ | Reg: 0.007240 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8059', '0.8111']
#    ↳ KAN decoder skip gains: ['0.7541', '0.7593']
# 📈 Epoch 168/500 | Train: 0.189677 | Val: 0.195655 ✅ | Reg: 0.007223 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8070', '0.8122']
#    ↳ KAN decoder skip gains: ['0.7554', '0.7608']
# 📈 Epoch 169/500 | Train: 0.190727 | Val: 0.195380 ✅ | Reg: 0.007206 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8079', '0.8132']
#    ↳ KAN decoder skip gains: ['0.7567', '0.7622']
# 📈 Epoch 170/500 | Train: 0.189917 | Val: 0.195135 ✅ | Reg: 0.007183 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8087', '0.8141']
#    ↳ KAN decoder skip gains: ['0.7579', '0.7635']
# 📈 Epoch 171/500 | Train: 0.189741 | Val: 0.194899 ✅ | Reg: 0.007162 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8096', '0.8151']
#    ↳ KAN decoder skip gains: ['0.7591', '0.7648']
# 📈 Epoch 172/500 | Train: 0.190327 | Val: 0.194690 ✅ | Reg: 0.007138 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8104', '0.8160']
#    ↳ KAN decoder skip gains: ['0.7602', '0.7661']
# 📈 Epoch 173/500 | Train: 0.190103 | Val: 0.194489 ✅ | Reg: 0.007112 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8112', '0.8168']
#    ↳ KAN decoder skip gains: ['0.7613', '0.7673']
# 📈 Epoch 174/500 | Train: 0.190622 | Val: 0.194311 ✅ | Reg: 0.007082 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8117', '0.8175']
#    ↳ KAN decoder skip gains: ['0.7623', '0.7683']
# 📈 Epoch 175/500 | Train: 0.189043 | Val: 0.194133 ✅ | Reg: 0.007052 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8124', '0.8183']
#    ↳ KAN decoder skip gains: ['0.7633', '0.7694']
# 📈 Epoch 176/500 | Train: 0.189455 | Val: 0.193984 ✅ | Reg: 0.007020 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8129', '0.8189']
#    ↳ KAN decoder skip gains: ['0.7642', '0.7704']
# 📈 Epoch 177/500 | Train: 0.188890 | Val: 0.193836 ✅ | Reg: 0.006987 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8135', '0.8196']
#    ↳ KAN decoder skip gains: ['0.7651', '0.7714']
# 📈 Epoch 178/500 | Train: 0.188195 | Val: 0.193689 ✅ | Reg: 0.006957 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8142', '0.8204']
#    ↳ KAN decoder skip gains: ['0.7660', '0.7725']
# 📈 Epoch 179/500 | Train: 0.188994 | Val: 0.193547 ✅ | Reg: 0.006928 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8149', '0.8211']
#    ↳ KAN decoder skip gains: ['0.7670', '0.7735']
# 📈 Epoch 180/500 | Train: 0.188963 | Val: 0.193419 ✅ | Reg: 0.006896 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8154', '0.8218']
#    ↳ KAN decoder skip gains: ['0.7678', '0.7744']
# 📈 Epoch 181/500 | Train: 0.188692 | Val: 0.193289 ✅ | Reg: 0.006865 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8161', '0.8226']
#    ↳ KAN decoder skip gains: ['0.7687', '0.7754']
# 📈 Epoch 182/500 | Train: 0.188262 | Val: 0.193178 ✅ | Reg: 0.006833 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8166', '0.8232']
#    ↳ KAN decoder skip gains: ['0.7695', '0.7763']
# 📈 Epoch 183/500 | Train: 0.187562 | Val: 0.193076 ✅ | Reg: 0.006797 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8171', '0.8238']
#    ↳ KAN decoder skip gains: ['0.7702', '0.7771']
# 📈 Epoch 184/500 | Train: 0.188381 | Val: 0.192977 ✅ | Reg: 0.006762 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8177', '0.8244']
#    ↳ KAN decoder skip gains: ['0.7710', '0.7779']
# 📈 Epoch 185/500 | Train: 0.187393 | Val: 0.192880 ✅ | Reg: 0.006729 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8182', '0.8251']
#    ↳ KAN decoder skip gains: ['0.7718', '0.7788']
# 📈 Epoch 186/500 | Train: 0.188251 | Val: 0.192796 ✅ | Reg: 0.006696 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8188', '0.8257']
#    ↳ KAN decoder skip gains: ['0.7725', '0.7797']
# 📈 Epoch 187/500 | Train: 0.187486 | Val: 0.192709 ✅ | Reg: 0.006665 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8195', '0.8264']
#    ↳ KAN decoder skip gains: ['0.7733', '0.7805']
# 📈 Epoch 188/500 | Train: 0.187656 | Val: 0.192641 ✅ | Reg: 0.006629 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8199', '0.8269']
#    ↳ KAN decoder skip gains: ['0.7739', '0.7812']
# 📈 Epoch 189/500 | Train: 0.187270 | Val: 0.192567 ✅ | Reg: 0.006594 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8205', '0.8276']
#    ↳ KAN decoder skip gains: ['0.7747', '0.7820']
# 📈 Epoch 190/500 | Train: 0.187928 | Val: 0.192502 ✅ | Reg: 0.006560 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8210', '0.8282']
#    ↳ KAN decoder skip gains: ['0.7754', '0.7828']
# 📈 Epoch 191/500 | Train: 0.186193 | Val: 0.192435 ✅ | Reg: 0.006528 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8216', '0.8288']
#    ↳ KAN decoder skip gains: ['0.7761', '0.7835']
# 📈 Epoch 192/500 | Train: 0.188239 | Val: 0.192381 ✅ | Reg: 0.006495 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8222', '0.8294']
#    ↳ KAN decoder skip gains: ['0.7768', '0.7843']
# 📈 Epoch 193/500 | Train: 0.187198 | Val: 0.192335 ✅ | Reg: 0.006459 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8227', '0.8300']
#    ↳ KAN decoder skip gains: ['0.7774', '0.7849']
# 📈 Epoch 194/500 | Train: 0.187127 | Val: 0.192292 ✅ | Reg: 0.006423 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8232', '0.8306']
#    ↳ KAN decoder skip gains: ['0.7780', '0.7856']
# 📈 Epoch 195/500 | Train: 0.187415 | Val: 0.192247 ✅ | Reg: 0.006387 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8237', '0.8311']
#    ↳ KAN decoder skip gains: ['0.7786', '0.7863']
# 📈 Epoch 196/500 | Train: 0.187421 | Val: 0.192205 ✅ | Reg: 0.006352 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8243', '0.8317']
#    ↳ KAN decoder skip gains: ['0.7792', '0.7869']
# 📈 Epoch 197/500 | Train: 0.187047 | Val: 0.192166 ✅ | Reg: 0.006318 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8249', '0.8324']
#    ↳ KAN decoder skip gains: ['0.7799', '0.7876']
# 📈 Epoch 198/500 | Train: 0.188059 | Val: 0.192128 ✅ | Reg: 0.006285 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8255', '0.8330']
#    ↳ KAN decoder skip gains: ['0.7805', '0.7883']
# 📈 Epoch 199/500 | Train: 0.187968 | Val: 0.192094 ✅ | Reg: 0.006249 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8260', '0.8335']
#    ↳ KAN decoder skip gains: ['0.7811', '0.7889']
# 📈 Epoch 200/500 | Train: 0.187155 | Val: 0.192066 ✅ | Reg: 0.006214 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8265', '0.8341']
#    ↳ KAN decoder skip gains: ['0.7817', '0.7895']
# 📈 Epoch 201/500 | Train: 0.187834 | Val: 0.192042 ✅ | Reg: 0.006179 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8270', '0.8346']
#    ↳ KAN decoder skip gains: ['0.7822', '0.7901']
# 📈 Epoch 202/500 | Train: 0.187187 | Val: 0.192017 ✅ | Reg: 0.006145 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8276', '0.8352']
#    ↳ KAN decoder skip gains: ['0.7828', '0.7908']
# 📈 Epoch 203/500 | Train: 0.187307 | Val: 0.191994 ✅ | Reg: 0.006110 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8281', '0.8358']
#    ↳ KAN decoder skip gains: ['0.7834', '0.7914']
# 📈 Epoch 204/500 | Train: 0.187574 | Val: 0.191970 ✅ | Reg: 0.006076 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8287', '0.8364']
#    ↳ KAN decoder skip gains: ['0.7840', '0.7920']
# 📈 Epoch 205/500 | Train: 0.186110 | Val: 0.191949 ✅ | Reg: 0.006044 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8293', '0.8370']
#    ↳ KAN decoder skip gains: ['0.7846', '0.7926']
# 📈 Epoch 206/500 | Train: 0.187128 | Val: 0.191929 ✅ | Reg: 0.006010 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8299', '0.8375']
#    ↳ KAN decoder skip gains: ['0.7852', '0.7932']
# 📈 Epoch 207/500 | Train: 0.187268 | Val: 0.191916 ✅ | Reg: 0.005976 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8304', '0.8381']
#    ↳ KAN decoder skip gains: ['0.7857', '0.7938']
# 📈 Epoch 208/500 | Train: 0.186617 | Val: 0.191899 ✅ | Reg: 0.005942 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8310', '0.8387']
#    ↳ KAN decoder skip gains: ['0.7863', '0.7944']
# 📈 Epoch 209/500 | Train: 0.188259 | Val: 0.191878 ✅ | Reg: 0.005910 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8316', '0.8393']
#    ↳ KAN decoder skip gains: ['0.7869', '0.7950']
# 📈 Epoch 210/500 | Train: 0.187189 | Val: 0.191863 ✅ | Reg: 0.005877 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8321', '0.8398']
#    ↳ KAN decoder skip gains: ['0.7874', '0.7955']
# 📈 Epoch 211/500 | Train: 0.186487 | Val: 0.191850 ✅ | Reg: 0.005841 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8326', '0.8403']
#    ↳ KAN decoder skip gains: ['0.7879', '0.7961']
# 📈 Epoch 212/500 | Train: 0.187635 | Val: 0.191833 ✅ | Reg: 0.005809 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8332', '0.8409']
#    ↳ KAN decoder skip gains: ['0.7885', '0.7967']
# 📈 Epoch 213/500 | Train: 0.187057 | Val: 0.191819 ✅ | Reg: 0.005778 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8338', '0.8415']
#    ↳ KAN decoder skip gains: ['0.7891', '0.7972']
# 📈 Epoch 214/500 | Train: 0.187262 | Val: 0.191811 ✅ | Reg: 0.005744 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8343', '0.8420']
#    ↳ KAN decoder skip gains: ['0.7896', '0.7978']
# 📈 Epoch 215/500 | Train: 0.185607 | Val: 0.191798 ✅ | Reg: 0.005711 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8349', '0.8426']
#    ↳ KAN decoder skip gains: ['0.7901', '0.7983']
# 📈 Epoch 216/500 | Train: 0.185169 | Val: 0.191790 ✅ | Reg: 0.005680 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8354', '0.8432']
#    ↳ KAN decoder skip gains: ['0.7907', '0.7989']
# 📈 Epoch 217/500 | Train: 0.186795 | Val: 0.191781 ✅ | Reg: 0.005648 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8360', '0.8437']
#    ↳ KAN decoder skip gains: ['0.7912', '0.7995']
# 📈 Epoch 218/500 | Train: 0.186896 | Val: 0.191773 ✅ | Reg: 0.005617 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8366', '0.8443']
#    ↳ KAN decoder skip gains: ['0.7918', '0.8000']
# 📈 Epoch 219/500 | Train: 0.186802 | Val: 0.191766 ✅ | Reg: 0.005586 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8372', '0.8449']
#    ↳ KAN decoder skip gains: ['0.7923', '0.8006']
# 📈 Epoch 220/500 | Train: 0.186178 | Val: 0.191762 ✅ | Reg: 0.005556 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8377', '0.8454']
#    ↳ KAN decoder skip gains: ['0.7929', '0.8012']
# 📈 Epoch 221/500 | Train: 0.185821 | Val: 0.191756 ✅ | Reg: 0.005524 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8383', '0.8460']
#    ↳ KAN decoder skip gains: ['0.7934', '0.8017']
# 📈 Epoch 222/500 | Train: 0.186760 | Val: 0.191743 ✅ | Reg: 0.005493 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8389', '0.8466']
#    ↳ KAN decoder skip gains: ['0.7939', '0.8022']
# 📈 Epoch 223/500 | Train: 0.186561 | Val: 0.191739 ✅ | Reg: 0.005463 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8394', '0.8471']
#    ↳ KAN decoder skip gains: ['0.7945', '0.8028']
# 📈 Epoch 224/500 | Train: 0.186868 | Val: 0.191733 ✅ | Reg: 0.005433 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8400', '0.8477']
#    ↳ KAN decoder skip gains: ['0.7950', '0.8033']
# 📈 Epoch 225/500 | Train: 0.187037 | Val: 0.191726 ✅ | Reg: 0.005403 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8406', '0.8482']
#    ↳ KAN decoder skip gains: ['0.7956', '0.8038']
# 📈 Epoch 226/500 | Train: 0.186705 | Val: 0.191725 ✅ | Reg: 0.005371 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8411', '0.8487']
#    ↳ KAN decoder skip gains: ['0.7960', '0.8043']
# 📈 Epoch 227/500 | Train: 0.187460 | Val: 0.191724 ✅ | Reg: 0.005341 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8417', '0.8493']
#    ↳ KAN decoder skip gains: ['0.7966', '0.8049']
# 📈 Epoch 228/500 | Train: 0.185610 | Val: 0.191718 ✅ | Reg: 0.005313 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8423', '0.8499']
#    ↳ KAN decoder skip gains: ['0.7972', '0.8055']
# 📈 Epoch 229/500 | Train: 0.186314 | Val: 0.191708 ✅ | Reg: 0.005286 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8429', '0.8506']
#    ↳ KAN decoder skip gains: ['0.7978', '0.8060']
# 📈 Epoch 230/500 | Train: 0.188280 | Val: 0.191703 ✅ | Reg: 0.005258 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8435', '0.8511']
#    ↳ KAN decoder skip gains: ['0.7983', '0.8065']
# 📈 Epoch 231/500 | Train: 0.186170 | Val: 0.191701 ✅ | Reg: 0.005229 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8441', '0.8517']
#    ↳ KAN decoder skip gains: ['0.7988', '0.8071']
# 📈 Epoch 232/500 | Train: 0.186572 | Val: 0.191699 ✅ | Reg: 0.005200 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8446', '0.8522']
#    ↳ KAN decoder skip gains: ['0.7993', '0.8076']
# 📈 Epoch 233/500 | Train: 0.186817 | Val: 0.191694 ✅ | Reg: 0.005170 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8452', '0.8527']
#    ↳ KAN decoder skip gains: ['0.7998', '0.8081']
# 📈 Epoch 234/500 | Train: 0.186423 | Val: 0.191686 ✅ | Reg: 0.005142 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8458', '0.8533']
#    ↳ KAN decoder skip gains: ['0.8004', '0.8086']
# 📈 Epoch 235/500 | Train: 0.186036 | Val: 0.191680 ✅ | Reg: 0.005116 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8464', '0.8539']
#    ↳ KAN decoder skip gains: ['0.8009', '0.8092']
# 📈 Epoch 236/500 | Train: 0.187361 | Val: 0.191678 ✅ | Reg: 0.005088 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8469', '0.8544']
#    ↳ KAN decoder skip gains: ['0.8015', '0.8097']
# 📈 Epoch 237/500 | Train: 0.186935 | Val: 0.191676 ✅ | Reg: 0.005060 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8475', '0.8550']
#    ↳ KAN decoder skip gains: ['0.8020', '0.8102']
# 📈 Epoch 238/500 | Train: 0.186226 | Val: 0.191667 ✅ | Reg: 0.005033 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8481', '0.8556']
#    ↳ KAN decoder skip gains: ['0.8025', '0.8107']
# 📈 Epoch 239/500 | Train: 0.186136 | Val: 0.191662 ✅ | Reg: 0.005007 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8487', '0.8562']
#    ↳ KAN decoder skip gains: ['0.8031', '0.8113']
# 📈 Epoch 240/500 | Train: 0.187757 | Val: 0.191659 ✅ | Reg: 0.004981 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8493', '0.8567']
#    ↳ KAN decoder skip gains: ['0.8036', '0.8118']
# 📈 Epoch 241/500 | Train: 0.187204 | Val: 0.191657 ✅ | Reg: 0.004954 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8499', '0.8573']
#    ↳ KAN decoder skip gains: ['0.8041', '0.8123']
# 📈 Epoch 242/500 | Train: 0.186943 | Val: 0.191658 ❌ | Reg: 0.004927 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8505', '0.8579']
#    ↳ KAN decoder skip gains: ['0.8047', '0.8128']
# 📈 Epoch 243/500 | Train: 0.186606 | Val: 0.191659 ❌ | Reg: 0.004901 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8510', '0.8584']
#    ↳ KAN decoder skip gains: ['0.8052', '0.8133']
# 📈 Epoch 244/500 | Train: 0.186805 | Val: 0.191660 ❌ | Reg: 0.004874 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8516', '0.8590']
#    ↳ KAN decoder skip gains: ['0.8057', '0.8138']
# 📈 Epoch 245/500 | Train: 0.186682 | Val: 0.191650 ✅ | Reg: 0.004849 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8522', '0.8596']
#    ↳ KAN decoder skip gains: ['0.8063', '0.8144']
# 📈 Epoch 246/500 | Train: 0.185169 | Val: 0.191649 ✅ | Reg: 0.004823 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8528', '0.8601']
#    ↳ KAN decoder skip gains: ['0.8068', '0.8149']
# 📈 Epoch 247/500 | Train: 0.186918 | Val: 0.191644 ✅ | Reg: 0.004799 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8534', '0.8607']
#    ↳ KAN decoder skip gains: ['0.8073', '0.8154']
# 📈 Epoch 248/500 | Train: 0.187444 | Val: 0.191636 ✅ | Reg: 0.004776 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8541', '0.8613']
#    ↳ KAN decoder skip gains: ['0.8079', '0.8160']
# 📈 Epoch 249/500 | Train: 0.186923 | Val: 0.191636 ✅ | Reg: 0.004750 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8546', '0.8618']
#    ↳ KAN decoder skip gains: ['0.8084', '0.8164']
# 📈 Epoch 250/500 | Train: 0.186234 | Val: 0.191634 ✅ | Reg: 0.004723 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8551', '0.8623']
#    ↳ KAN decoder skip gains: ['0.8089', '0.8169']
# 📈 Epoch 251/500 | Train: 0.186798 | Val: 0.191635 ❌ | Reg: 0.004698 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8557', '0.8629']
#    ↳ KAN decoder skip gains: ['0.8094', '0.8174']
# 📈 Epoch 252/500 | Train: 0.186571 | Val: 0.191631 ✅ | Reg: 0.004676 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8564', '0.8635']
#    ↳ KAN decoder skip gains: ['0.8100', '0.8180']
# 📈 Epoch 253/500 | Train: 0.186419 | Val: 0.191631 ❌ | Reg: 0.004653 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8570', '0.8641']
#    ↳ KAN decoder skip gains: ['0.8105', '0.8185']
# 📈 Epoch 254/500 | Train: 0.186037 | Val: 0.191628 ✅ | Reg: 0.004628 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8575', '0.8646']
#    ↳ KAN decoder skip gains: ['0.8110', '0.8190']
# 📈 Epoch 255/500 | Train: 0.186524 | Val: 0.191624 ✅ | Reg: 0.004604 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8581', '0.8652']
#    ↳ KAN decoder skip gains: ['0.8116', '0.8195']
# 📈 Epoch 256/500 | Train: 0.185756 | Val: 0.191630 ❌ | Reg: 0.004580 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8587', '0.8657']
#    ↳ KAN decoder skip gains: ['0.8121', '0.8200']
# 📈 Epoch 257/500 | Train: 0.186028 | Val: 0.191632 ❌ | Reg: 0.004557 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8593', '0.8663']
#    ↳ KAN decoder skip gains: ['0.8126', '0.8205']
# 📈 Epoch 258/500 | Train: 0.186773 | Val: 0.191636 ❌ | Reg: 0.004534 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8599', '0.8669']
#    ↳ KAN decoder skip gains: ['0.8131', '0.8210']
# 📈 Epoch 259/500 | Train: 0.188057 | Val: 0.191632 ✅ | Reg: 0.004511 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8604', '0.8674']
#    ↳ KAN decoder skip gains: ['0.8136', '0.8215']
# 📈 Epoch 260/500 | Train: 0.186152 | Val: 0.191632 ✅ | Reg: 0.004488 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8610', '0.8680']
#    ↳ KAN decoder skip gains: ['0.8142', '0.8220']
# 📈 Epoch 261/500 | Train: 0.185438 | Val: 0.191630 ✅ | Reg: 0.004467 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8617', '0.8686']
#    ↳ KAN decoder skip gains: ['0.8148', '0.8226']
# 📈 Epoch 262/500 | Train: 0.187377 | Val: 0.191630 ❌ | Reg: 0.004444 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8622', '0.8691']
#    ↳ KAN decoder skip gains: ['0.8153', '0.8230']
# 📈 Epoch 263/500 | Train: 0.187030 | Val: 0.191628 ✅ | Reg: 0.004421 | LR: 1.00e-04
#    ↳ KAN encoder skip gains: ['0.8628', '0.8697']
# ...
# 📈 Epoch 300/500 | Train: 0.185902 | Val: 0.191612 ❌ | Reg: 0.004006 | LR: 2.50e-05
#    ↳ KAN encoder skip gains: ['0.8743', '0.8807']
#    ↳ KAN decoder skip gains: ['0.8260', '0.8333']
# 📈 Epoch 301/500 | Train: 0.187087 | Val: 0.191612 ❌ | Reg: 0.004001 | LR: 2.50e-05
#    ↳ KAN encoder skip gains: ['0.8745', '0.8808']
#    ↳ KAN decoder skip gains: ['0.8262', '0.8334']
# 📈 Epoch 302/500 | Train: 0.185951 | Val: 0.191610 ✅ | Reg: 0.003996 | LR: 2.50e-05
#    ↳ KAN encoder skip gains: ['0.8747', '0.8810']
#    ↳ KAN decoder skip gains: ['0.8263', '0.8336']
# 📈 Epoch 303/500 | Train: 0.187402 | Val: 0.191610 ❌ | Reg: 0.003991 | LR: 1.25e-05
#    ↳ KAN encoder skip gains: ['0.8748', '0.8811']
#    ↳ KAN decoder skip gains: ['0.8265', '0.8337']
# 📈 Epoch 304/500 | Train: 0.187027 | Val: 0.191610 ❌ | Reg: 0.003987 | LR: 1.25e-05
#    ↳ KAN encoder skip gains: ['0.8749', '0.8812']
#    ↳ KAN decoder skip gains: ['0.8265', '0.8338']
# 📈 Epoch 305/500 | Train: 0.186345 | Val: 0.191610 ❌ | Reg: 0.003984 | LR: 1.25e-05
#    ↳ KAN encoder skip gains: ['0.8750', '0.8813']
#    ↳ KAN decoder skip gains: ['0.8266', '0.8338']
# 📈 Epoch 306/500 | Train: 0.187223 | Val: 0.191611 ❌ | Reg: 0.003981 | LR: 1.25e-05
#    ↳ KAN encoder skip gains: ['0.8750', '0.8813']
#    ↳ KAN decoder skip gains: ['0.8267', '0.8339']
# 📈 Epoch 307/500 | Train: 0.186907 | Val: 0.191609 ✅ | Reg: 0.003979 | LR: 1.25e-05
#    ↳ KAN encoder skip gains: ['0.8751', '0.8814']
#    ↳ KAN decoder skip gains: ['0.8267', '0.8339']
# 📈 Epoch 308/500 | Train: 0.186808 | Val: 0.191609 ✅ | Reg: 0.003976 | LR: 1.25e-05
#    ↳ KAN encoder skip gains: ['0.8752', '0.8815']
#    ↳ KAN decoder skip gains: ['0.8268', '0.8340']
# 📈 Epoch 309/500 | Train: 0.186707 | Val: 0.191609 ❌ | Reg: 0.003974 | LR: 1.25e-05
#    ↳ KAN encoder skip gains: ['0.8753', '0.8816']
#    ↳ KAN decoder skip gains: ['0.8269', '0.8341']
# 📈 Epoch 310/500 | Train: 0.186788 | Val: 0.191609 ✅ | Reg: 0.003971 | LR: 1.25e-05
#    ↳ KAN encoder skip gains: ['0.8754', '0.8816']
#    ↳ KAN decoder skip gains: ['0.8269', '0.8341']
# 📈 Epoch 311/500 | Train: 0.186466 | Val: 0.191609 ✅ | Reg: 0.003969 | LR: 1.25e-05
#    ↳ KAN encoder skip gains: ['0.8754', '0.8817']
#    ↳ KAN decoder skip gains: ['0.8270', '0.8342']
# 📈 Epoch 312/500 | Train: 0.186686 | Val: 0.191609 ❌ | Reg: 0.003966 | LR: 1.25e-05
#    ↳ KAN encoder skip gains: ['0.8755', '0.8818']
#    ↳ KAN decoder skip gains: ['0.8271', '0.8343']
# 📈 Epoch 313/500 | Train: 0.186311 | Val: 0.191609 ❌ | Reg: 0.003964 | LR: 1.25e-05
#    ↳ KAN encoder skip gains: ['0.8756', '0.8819']
#    ↳ KAN decoder skip gains: ['0.8271', '0.8343']
# 📈 Epoch 314/500 | Train: 0.186701 | Val: 0.191609 ✅ | Reg: 0.003961 | LR: 1.25e-05
#    ↳ KAN encoder skip gains: ['0.8757', '0.8819']
#    ↳ KAN decoder skip gains: ['0.8272', '0.8344']
# 📈 Epoch 315/500 | Train: 0.185761 | Val: 0.191609 ✅ | Reg: 0.003959 | LR: 1.25e-05
#    ↳ KAN encoder skip gains: ['0.8757', '0.8820']
#    ↳ KAN decoder skip gains: ['0.8273', '0.8345']
# 📈 Epoch 316/500 | Train: 0.186576 | Val: 0.191608 ✅ | Reg: 0.003957 | LR: 1.25e-05
#    ↳ KAN encoder skip gains: ['0.8758', '0.8821']
#    ↳ KAN decoder skip gains: ['0.8274', '0.8345']
# 📈 Epoch 317/500 | Train: 0.186140 | Val: 0.191608 ✅ | Reg: 0.003954 | LR: 1.25e-05
#    ↳ KAN encoder skip gains: ['0.8759', '0.8822']
#    ↳ KAN decoder skip gains: ['0.8274', '0.8346']
# 📈 Epoch 318/500 | Train: 0.186694 | Val: 0.191608 ❌ | Reg: 0.003952 | LR: 1.25e-05
#    ↳ KAN encoder skip gains: ['0.8760', '0.8822']
#    ↳ KAN decoder skip gains: ['0.8275', '0.8347']
# 📈 Epoch 319/500 | Train: 0.186405 | Val: 0.191608 ❌ | Reg: 0.003949 | LR: 6.25e-06
#    ↳ KAN encoder skip gains: ['0.8761', '0.8823']
#    ↳ KAN decoder skip gains: ['0.8276', '0.8347']
# 📈 Epoch 320/500 | Train: 0.186917 | Val: 0.191608 ✅ | Reg: 0.003947 | LR: 6.25e-06
#    ↳ KAN encoder skip gains: ['0.8761', '0.8823']
#    ↳ KAN decoder skip gains: ['0.8276', '0.8348']
# 📈 Epoch 321/500 | Train: 0.185508 | Val: 0.191608 ❌ | Reg: 0.003945 | LR: 6.25e-06
#    ↳ KAN encoder skip gains: ['0.8761', '0.8824']
#    ↳ KAN decoder skip gains: ['0.8276', '0.8348']
# 📈 Epoch 322/500 | Train: 0.186010 | Val: 0.191608 ❌ | Reg: 0.003944 | LR: 6.25e-06
#    ↳ KAN encoder skip gains: ['0.8762', '0.8824']
#    ↳ KAN decoder skip gains: ['0.8277', '0.8349']
# 📈 Epoch 323/500 | Train: 0.185896 | Val: 0.191608 ❌ | Reg: 0.003943 | LR: 6.25e-06
#    ↳ KAN encoder skip gains: ['0.8762', '0.8825']
#    ↳ KAN decoder skip gains: ['0.8277', '0.8349']
# 📈 Epoch 324/500 | Train: 0.186512 | Val: 0.191608 ✅ | Reg: 0.003942 | LR: 6.25e-06
#    ↳ KAN encoder skip gains: ['0.8763', '0.8825']
#    ↳ KAN decoder skip gains: ['0.8278', '0.8349']
# 📈 Epoch 325/500 | Train: 0.186564 | Val: 0.191608 ✅ | Reg: 0.003941 | LR: 6.25e-06
#    ↳ KAN encoder skip gains: ['0.8763', '0.8825']
#    ↳ KAN decoder skip gains: ['0.8278', '0.8350']
# 📈 Epoch 326/500 | Train: 0.186008 | Val: 0.191608 ✅ | Reg: 0.003939 | LR: 6.25e-06
#    ↳ KAN encoder skip gains: ['0.8763', '0.8826']
#    ↳ KAN decoder skip gains: ['0.8278', '0.8350']
# 📈 Epoch 327/500 | Train: 0.185689 | Val: 0.191608 ❌ | Reg: 0.003938 | LR: 6.25e-06
#    ↳ KAN encoder skip gains: ['0.8764', '0.8826']
#    ↳ KAN decoder skip gains: ['0.8279', '0.8350']
# 📈 Epoch 328/500 | Train: 0.187439 | Val: 0.191608 ❌ | Reg: 0.003937 | LR: 6.25e-06
#    ↳ KAN encoder skip gains: ['0.8764', '0.8827']
#    ↳ KAN decoder skip gains: ['0.8279', '0.8351']
# 📈 Epoch 329/500 | Train: 0.185781 | Val: 0.191608 ❌ | Reg: 0.003936 | LR: 6.25e-06
#    ↳ KAN encoder skip gains: ['0.8765', '0.8827']
#    ↳ KAN decoder skip gains: ['0.8279', '0.8351']
# 📈 Epoch 330/500 | Train: 0.186934 | Val: 0.191608 ❌ | Reg: 0.003935 | LR: 6.25e-06
#    ↳ KAN encoder skip gains: ['0.8765', '0.8827']
#    ↳ KAN decoder skip gains: ['0.8280', '0.8351']
# 📈 Epoch 331/500 | Train: 0.186950 | Val: 0.191608 ✅ | Reg: 0.003933 | LR: 6.25e-06
#    ↳ KAN encoder skip gains: ['0.8765', '0.8828']
#    ↳ KAN decoder skip gains: ['0.8280', '0.8352']
# 📈 Epoch 332/500 | Train: 0.187634 | Val: 0.191608 ✅ | Reg: 0.003932 | LR: 6.25e-06
#    ↳ KAN encoder skip gains: ['0.8766', '0.8828']
#    ↳ KAN decoder skip gains: ['0.8280', '0.8352']
# 📈 Epoch 333/500 | Train: 0.186873 | Val: 0.191608 ✅ | Reg: 0.003931 | LR: 6.25e-06
#    ↳ KAN encoder skip gains: ['0.8766', '0.8828']
#    ↳ KAN decoder skip gains: ['0.8281', '0.8352']
# 📈 Epoch 334/500 | Train: 0.186041 | Val: 0.191608 ❌ | Reg: 0.003929 | LR: 6.25e-06
#    ↳ KAN encoder skip gains: ['0.8767', '0.8829']
#    ↳ KAN decoder skip gains: ['0.8281', '0.8353']
# 📈 Epoch 335/500 | Train: 0.186010 | Val: 0.191608 ❌ | Reg: 0.003928 | LR: 3.13e-06
#    ↳ KAN encoder skip gains: ['0.8767', '0.8829']
#    ↳ KAN decoder skip gains: ['0.8281', '0.8353']
# 📈 Epoch 336/500 | Train: 0.186566 | Val: 0.191608 ✅ | Reg: 0.003927 | LR: 3.13e-06
#    ↳ KAN encoder skip gains: ['0.8767', '0.8829']
#    ↳ KAN decoder skip gains: ['0.8282', '0.8353']
# 📈 Epoch 337/500 | Train: 0.186700 | Val: 0.191608 ✅ | Reg: 0.003926 | LR: 3.13e-06
#    ↳ KAN encoder skip gains: ['0.8767', '0.8830']
#    ↳ KAN decoder skip gains: ['0.8282', '0.8353']
# 📈 Epoch 338/500 | Train: 0.187255 | Val: 0.191608 ❌ | Reg: 0.003926 | LR: 3.13e-06
#    ↳ KAN encoder skip gains: ['0.8768', '0.8830']
#    ↳ KAN decoder skip gains: ['0.8282', '0.8354']
# 📈 Epoch 339/500 | Train: 0.186525 | Val: 0.191608 ✅ | Reg: 0.003925 | LR: 3.13e-06
#    ↳ KAN encoder skip gains: ['0.8768', '0.8830']
#    ↳ KAN decoder skip gains: ['0.8282', '0.8354']
# 📈 Epoch 340/500 | Train: 0.186117 | Val: 0.191608 ❌ | Reg: 0.003925 | LR: 3.13e-06
#    ↳ KAN encoder skip gains: ['0.8768', '0.8830']
#    ↳ KAN decoder skip gains: ['0.8282', '0.8354']
# 📈 Epoch 341/500 | Train: 0.186527 | Val: 0.191608 ✅ | Reg: 0.003924 | LR: 3.13e-06
#    ↳ KAN encoder skip gains: ['0.8768', '0.8830']
#    ↳ KAN decoder skip gains: ['0.8283', '0.8354']
# 📈 Epoch 342/500 | Train: 0.186243 | Val: 0.191608 ✅ | Reg: 0.003923 | LR: 3.13e-06
#    ↳ KAN encoder skip gains: ['0.8768', '0.8831']
#    ↳ KAN decoder skip gains: ['0.8283', '0.8354']
# 📈 Epoch 343/500 | Train: 0.187283 | Val: 0.191608 ✅ | Reg: 0.003923 | LR: 3.13e-06
#    ↳ KAN encoder skip gains: ['0.8769', '0.8831']
#    ↳ KAN decoder skip gains: ['0.8283', '0.8355']
# 📈 Epoch 344/500 | Train: 0.186529 | Val: 0.191608 ❌ | Reg: 0.003922 | LR: 3.13e-06
#    ↳ KAN encoder skip gains: ['0.8769', '0.8831']
#    ↳ KAN decoder skip gains: ['0.8283', '0.8355']
# 📈 Epoch 345/500 | Train: 0.185869 | Val: 0.191608 ✅ | Reg: 0.003922 | LR: 3.13e-06
#    ↳ KAN encoder skip gains: ['0.8769', '0.8831']
#    ↳ KAN decoder skip gains: ['0.8283', '0.8355']
# 📈 Epoch 346/500 | Train: 0.186235 | Val: 0.191608 ❌ | Reg: 0.003921 | LR: 3.13e-06
#    ↳ KAN encoder skip gains: ['0.8769', '0.8831']
#    ↳ KAN decoder skip gains: ['0.8284', '0.8355']
# 📈 Epoch 347/500 | Train: 0.186831 | Val: 0.191608 ✅ | Reg: 0.003920 | LR: 3.13e-06
#    ↳ KAN encoder skip gains: ['0.8770', '0.8832']
#    ↳ KAN decoder skip gains: ['0.8284', '0.8355']
# 📈 Epoch 348/500 | Train: 0.185500 | Val: 0.191608 ✅ | Reg: 0.003920 | LR: 3.13e-06
#    ↳ KAN encoder skip gains: ['0.8770', '0.8832']
#    ↳ KAN decoder skip gains: ['0.8284', '0.8355']
# 📈 Epoch 349/500 | Train: 0.186445 | Val: 0.191608 ✅ | Reg: 0.003919 | LR: 3.13e-06
#    ↳ KAN encoder skip gains: ['0.8770', '0.8832']
#    ↳ KAN decoder skip gains: ['0.8284', '0.8356']
# 📈 Epoch 350/500 | Train: 0.186309 | Val: 0.191608 ❌ | Reg: 0.003918 | LR: 3.13e-06
#    ↳ KAN encoder skip gains: ['0.8770', '0.8832']
#    ↳ KAN decoder skip gains: ['0.8284', '0.8356']
# 📈 Epoch 351/500 | Train: 0.187307 | Val: 0.191608 ✅ | Reg: 0.003918 | LR: 1.56e-06
#    ↳ KAN encoder skip gains: ['0.8770', '0.8833']
#    ↳ KAN decoder skip gains: ['0.8285', '0.8356']
# 📈 Epoch 352/500 | Train: 0.187285 | Val: 0.191608 ✅ | Reg: 0.003917 | LR: 1.56e-06
#    ↳ KAN encoder skip gains: ['0.8770', '0.8833']
#    ↳ KAN decoder skip gains: ['0.8285', '0.8356']
# 📈 Epoch 353/500 | Train: 0.188038 | Val: 0.191608 ✅ | Reg: 0.003917 | LR: 1.56e-06
#    ↳ KAN encoder skip gains: ['0.8771', '0.8833']
#    ↳ KAN decoder skip gains: ['0.8285', '0.8356']
# 📈 Epoch 354/500 | Train: 0.186546 | Val: 0.191608 ❌ | Reg: 0.003917 | LR: 1.56e-06
#    ↳ KAN encoder skip gains: ['0.8771', '0.8833']
#    ↳ KAN decoder skip gains: ['0.8285', '0.8356']
# 📈 Epoch 355/500 | Train: 0.186034 | Val: 0.191608 ❌ | Reg: 0.003916 | LR: 1.56e-06
#    ↳ KAN encoder skip gains: ['0.8771', '0.8833']
#    ↳ KAN decoder skip gains: ['0.8285', '0.8356']
# 📈 Epoch 356/500 | Train: 0.186611 | Val: 0.191607 ✅ | Reg: 0.003916 | LR: 1.56e-06
#    ↳ KAN encoder skip gains: ['0.8771', '0.8833']
#    ↳ KAN decoder skip gains: ['0.8285', '0.8356']
# 📈 Epoch 357/500 | Train: 0.186936 | Val: 0.191607 ✅ | Reg: 0.003916 | LR: 1.56e-06
#    ↳ KAN encoder skip gains: ['0.8771', '0.8833']
#    ↳ KAN decoder skip gains: ['0.8285', '0.8357']
# 📈 Epoch 358/500 | Train: 0.186565 | Val: 0.191607 ❌ | Reg: 0.003915 | LR: 1.56e-06
#    ↳ KAN encoder skip gains: ['0.8771', '0.8833']
#    ↳ KAN decoder skip gains: ['0.8285', '0.8357']
# 📈 Epoch 359/500 | Train: 0.186643 | Val: 0.191608 ❌ | Reg: 0.003915 | LR: 1.56e-06
#    ↳ KAN encoder skip gains: ['0.8771', '0.8833']
#    ↳ KAN decoder skip gains: ['0.8285', '0.8357']
# 📈 Epoch 360/500 | Train: 0.187007 | Val: 0.191607 ✅ | Reg: 0.003915 | LR: 1.56e-06
#    ↳ KAN encoder skip gains: ['0.8771', '0.8833']
#    ↳ KAN decoder skip gains: ['0.8285', '0.8357']
# 📈 Epoch 361/500 | Train: 0.186587 | Val: 0.191607 ❌ | Reg: 0.003914 | LR: 1.56e-06
#    ↳ KAN encoder skip gains: ['0.8771', '0.8834']
#    ↳ KAN decoder skip gains: ['0.8286', '0.8357']
# 📈 Epoch 362/500 | Train: 0.186443 | Val: 0.191608 ❌ | Reg: 0.003914 | LR: 1.56e-06
#    ↳ KAN encoder skip gains: ['0.8772', '0.8834']
#    ↳ KAN decoder skip gains: ['0.8286', '0.8357']
# 📈 Epoch 363/500 | Train: 0.187907 | Val: 0.191608 ❌ | Reg: 0.003914 | LR: 1.56e-06
#    ↳ KAN encoder skip gains: ['0.8772', '0.8834']
#    ↳ KAN decoder skip gains: ['0.8286', '0.8357']
# 📈 Epoch 364/500 | Train: 0.185486 | Val: 0.191608 ✅ | Reg: 0.003913 | LR: 1.56e-06
#    ↳ KAN encoder skip gains: ['0.8772', '0.8834']
#    ↳ KAN decoder skip gains: ['0.8286', '0.8357']
# 📈 Epoch 365/500 | Train: 0.187757 | Val: 0.191608 ❌ | Reg: 0.003913 | LR: 1.56e-06
#    ↳ KAN encoder skip gains: ['0.8772', '0.8834']
#    ↳ KAN decoder skip gains: ['0.8286', '0.8357']
# 📈 Epoch 366/500 | Train: 0.186266 | Val: 0.191608 ✅ | Reg: 0.003913 | LR: 1.56e-06
#    ↳ KAN encoder skip gains: ['0.8772', '0.8834']
#    ↳ KAN decoder skip gains: ['0.8286', '0.8357']
# 📈 Epoch 367/500 | Train: 0.186946 | Val: 0.191608 ✅ | Reg: 0.003913 | LR: 7.81e-07
#    ↳ KAN encoder skip gains: ['0.8772', '0.8834']
#    ↳ KAN decoder skip gains: ['0.8286', '0.8357']
# 📈 Epoch 368/500 | Train: 0.187288 | Val: 0.191608 ❌ | Reg: 0.003912 | LR: 7.81e-07
#    ↳ KAN encoder skip gains: ['0.8772', '0.8834']
#    ↳ KAN decoder skip gains: ['0.8286', '0.8358']
# 📈 Epoch 369/500 | Train: 0.186714 | Val: 0.191608 ❌ | Reg: 0.003912 | LR: 7.81e-07
#    ↳ KAN encoder skip gains: ['0.8772', '0.8834']
#    ↳ KAN decoder skip gains: ['0.8286', '0.8358']
# 📈 Epoch 370/500 | Train: 0.186221 | Val: 0.191608 ❌ | Reg: 0.003912 | LR: 7.81e-07
#    ↳ KAN encoder skip gains: ['0.8772', '0.8834']
#    ↳ KAN decoder skip gains: ['0.8286', '0.8358']
# 📈 Epoch 371/500 | Train: 0.187182 | Val: 0.191607 ✅ | Reg: 0.003912 | LR: 7.81e-07
#    ↳ KAN encoder skip gains: ['0.8772', '0.8834']
#    ↳ KAN decoder skip gains: ['0.8286', '0.8358']
# 📈 Epoch 372/500 | Train: 0.186517 | Val: 0.191607 ✅ | Reg: 0.003912 | LR: 7.81e-07
#    ↳ KAN encoder skip gains: ['0.8772', '0.8834']
#    ↳ KAN decoder skip gains: ['0.8286', '0.8358']
# 📈 Epoch 373/500 | Train: 0.186768 | Val: 0.191607 ❌ | Reg: 0.003911 | LR: 7.81e-07
#    ↳ KAN encoder skip gains: ['0.8772', '0.8834']
#    ↳ KAN decoder skip gains: ['0.8286', '0.8358']
# 📈 Epoch 374/500 | Train: 0.186217 | Val: 0.191607 ❌ | Reg: 0.003911 | LR: 7.81e-07
#    ↳ KAN encoder skip gains: ['0.8772', '0.8835']
#    ↳ KAN decoder skip gains: ['0.8286', '0.8358']
# 📈 Epoch 375/500 | Train: 0.186352 | Val: 0.191607 ❌ | Reg: 0.003911 | LR: 7.81e-07
#    ↳ KAN encoder skip gains: ['0.8773', '0.8835']
#    ↳ KAN decoder skip gains: ['0.8287', '0.8358']
# 📈 Epoch 376/500 | Train: 0.185913 | Val: 0.191607 ✅ | Reg: 0.003911 | LR: 7.81e-07
#    ↳ KAN encoder skip gains: ['0.8773', '0.8835']
#    ↳ KAN decoder skip gains: ['0.8287', '0.8358']
# 📈 Epoch 377/500 | Train: 0.186431 | Val: 0.191607 ❌ | Reg: 0.003911 | LR: 7.81e-07
#    ↳ KAN encoder skip gains: ['0.8773', '0.8835']
#    ↳ KAN decoder skip gains: ['0.8287', '0.8358']
# 📈 Epoch 378/500 | Train: 0.187376 | Val: 0.191607 ❌ | Reg: 0.003911 | LR: 7.81e-07
#    ↳ KAN encoder skip gains: ['0.8773', '0.8835']
#    ↳ KAN decoder skip gains: ['0.8287', '0.8358']
# 📈 Epoch 379/500 | Train: 0.187378 | Val: 0.191607 ✅ | Reg: 0.003910 | LR: 7.81e-07
#    ↳ KAN encoder skip gains: ['0.8773', '0.8835']
#    ↳ KAN decoder skip gains: ['0.8287', '0.8358']
# 📈 Epoch 380/500 | Train: 0.185714 | Val: 0.191607 ❌ | Reg: 0.003910 | LR: 7.81e-07
#    ↳ KAN encoder skip gains: ['0.8773', '0.8835']
#    ↳ KAN decoder skip gains: ['0.8287', '0.8358']
# 📈 Epoch 381/500 | Train: 0.186327 | Val: 0.191607 ❌ | Reg: 0.003910 | LR: 7.81e-07
#    ↳ KAN encoder skip gains: ['0.8773', '0.8835']
#    ↳ KAN decoder skip gains: ['0.8287', '0.8358']
# 📈 Epoch 382/500 | Train: 0.186876 | Val: 0.191607 ✅ | Reg: 0.003910 | LR: 7.81e-07
#    ↳ KAN encoder skip gains: ['0.8773', '0.8835']
#    ↳ KAN decoder skip gains: ['0.8287', '0.8358']
# 📈 Epoch 383/500 | Train: 0.187519 | Val: 0.191607 ❌ | Reg: 0.003910 | LR: 3.91e-07
#    ↳ KAN encoder skip gains: ['0.8773', '0.8835']
#    ↳ KAN decoder skip gains: ['0.8287', '0.8358']
# 📈 Epoch 384/500 | Train: 0.185977 | Val: 0.191607 ❌ | Reg: 0.003910 | LR: 3.91e-07
#    ↳ KAN encoder skip gains: ['0.8773', '0.8835']
#    ↳ KAN decoder skip gains: ['0.8287', '0.8358']
# 📈 Epoch 385/500 | Train: 0.186720 | Val: 0.191608 ❌ | Reg: 0.003910 | LR: 3.91e-07
#    ↳ KAN encoder skip gains: ['0.8773', '0.8835']
#    ↳ KAN decoder skip gains: ['0.8287', '0.8358']
# 📈 Epoch 386/500 | Train: 0.185253 | Val: 0.191608 ❌ | Reg: 0.003910 | LR: 3.91e-07
#    ↳ KAN encoder skip gains: ['0.8773', '0.8835']
#    ↳ KAN decoder skip gains: ['0.8287', '0.8358']
# 🛑 Early stopping à l'époque 387

# %%
plot_training_history(history, config)

# %%
# plot les graphes pour facteurs latents
# Out:
# 🔍 Analyse du bottleneck (espace latent)...

# %%
def create_kan_model(config, input_dim):
    """Crée un modèle KAN avec la configuration donnée"""
    from models.ae_kan import KANAutoencoder
    
    return KANAutoencoder(
        input_dim=input_dim,
        k=config['latent_dim'],
        hidden_dims=config['hidden_dims'],
        basis_type=config['basis_type'],
        M=config['M_value'],
        poly_degree=config['poly_degree'],
        xmin=config['xmin'],
        xmax=config['xmax'],
        dropout_p=config['dropout_p'],
        use_silu=config['use_silu'],
        
        # LOSS
        loss_type=config['loss_type'],
        huber_delta=config['huber_delta'],
        
        # Régularisations KAN
        lambda_alpha=config['lambda_alpha'],
        lambda_group=config['lambda_group'],
        lambda_tv=config['lambda_tv'],
        lambda_poly_decay=config['lambda_poly_decay'],
        lambda_skip_l2=config['lambda_skip_l2'],
        
        # Skip connections
        use_global_skip=config['use_global_skip'],
        use_skip=config['use_skip'],
        skip_init=config['skip_init'],
        skip_gain=config['skip_gain']
    )

def train_kan_model(model, X_train, training_config, device="cuda", model_name="model"):
    
    history = model.fit(
        X_train,
        batch_size=training_config['batch_size'],
        epochs=training_config['epochs'],
        learning_rate=training_config['learning_rate'],
        weight_decay=training_config['weight_decay'],
        lambda_reg=training_config['lambda_reg'],
        patience=training_config['patience'],
        model_path=f'results/grid_search_{model_name}.pth'
    )
    
    return {
        'history': history,
        'best_val_loss': min(history['val_loss']),
        'final_train_loss': history['train_loss'][-1],
        'final_val_loss': history['val_loss'][-1],
        'epochs_trained': len(history['train_loss']),
        'training_time': history['training_time']
    }

# def evaluate_model(model, X_test, W_test, device):
#     """Évalue un modèle sur l'ensemble de test"""
#     model.eval()
    
#     with torch.no_grad():
#         X_test_reconstructed, latent_test = model(X_test)
        
#         # Conversion en numpy
#         X_test_np = X_test.cpu().numpy()
#         X_test_recon_np = X_test_reconstructed.cpu().numpy()
#         W_test_np = W_test.cpu().numpy()
        
#         # Métriques pondérées
#         mse_weighted = np.sum(W_test_np * (X_test_np - X_test_recon_np)**2) / np.sum(W_test_np)
#         mae_weighted = np.sum(W_test_np * np.abs(X_test_np - X_test_recon_np)) / np.sum(W_test_np)
        
#         return {
#             'mse_weighted': mse_weighted,
#             'mae_weighted': mae_weighted,
#             'rmse_weighted': np.sqrt(mse_weighted),
#             'reconstruction_error': np.mean((X_test_np - X_test_recon_np)**2)
#         }

# %%
kan = create_kan_model(config, input_dim)
train_kan_model(kan, X_train, config)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 kan = create_kan_model(config, input_dim)
# ----> 2 train_kan_model(kan, X_train, config)
#
# Cell In[17], line 37, in train_kan_model(model, X_train, training_config, device, model_name)
#      35 def train_kan_model(model, X_train, training_config, device="cuda", model_name="model"):
# ---> 37     history = model.fit(
#      38         X_train,
#      39         batch_size=training_config['batch_size'],
#      40         epochs=training_config['epochs'],
#      41         learning_rate=training_config['learning_rate'],
#      42         weight_decay=training_config['weight_decay'],
#      43         lambda_reg=training_config['lambda_reg'],
#      44         patience=training_config['patience'],
#      45         model_path=f'results/grid_search_{model_name}.pth'
#      46     )
#      48     return {
#      49         'history': history,
#      50         'best_val_loss': min(history['val_loss']),
#    (...)
#      54         'training_time': history['training_time']
#      55     }
#
# TypeError: KANAutoencoder.fit() got an unexpected keyword argument 'model_path'
